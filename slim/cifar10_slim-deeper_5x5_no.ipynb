# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
# %pylab
# %matplotlib inline
import os
import math
import time
import tensorflow as tf
from datasets import dataset_utils,cifar10
from tensorflow.contrib import slim
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
dropout_keep_prob=0.8
image_size = 32
step=20000
learning_rate=0.0002
train_dir = '/tmp/cifar10/5deep'

# %%
cifar10_data_dir='/media/ramdisk/data/cifar10'

# %%
display_step=2

with tf.Graph().as_default(): 
    dataset = cifar10.get_split('train', cifar10_data_dir)
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
        dataset, common_queue_capacity=32, common_queue_min=1)
    image, label = data_provider.get(['image', 'label'])

    with tf.Session() as sess:    
        with slim.queues.QueueRunners(sess):
            for i in range(display_step):
                np_image, np_label = sess.run([image, label])
                height, width, _ = np_image.shape
                class_name = name = dataset.labels_to_names[np_label]
                
                plt.figure()
                plt.imshow(np_image)
                plt.title('%s, %d x %d' % (name, height, width))
                plt.axis('off')
                plt.show()

# %%
def cnn_relu(images, num_classes, is_training):
    #https://github.com/agrawalnishant/tensorflow-1/tree/master/tensorflow/contrib/slim 
    ##vgg와  cifarndet을 참조함
    with slim.arg_scope([slim.max_pool2d], stride=2): 

        net = slim.repeat(images,2, slim.conv2d, 64, [5, 5], scope='conv1',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool1')
        net = slim.repeat(net, 3, slim.conv2d, 128, [5, 5], scope='conv2',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool2')
        net = slim.repeat(net, 5, slim.conv2d, 256, [5, 5], scope='conv3',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool3')
        net = slim.repeat(net, 6, slim.conv2d, 512, [5, 5], scope='conv4',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool4')

       
        net = slim.conv2d(net, 1024, [2, 2], padding="VALID", scope='fc6')
        net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                         scope='dropout6')
        net = slim.conv2d(net, 1024, [1, 1], scope='fc8', activation_fn=None)
        net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                           scope='dropout7')
        net = slim.conv2d(net, num_classes, [1, 1],
                          activation_fn=None,
                          normalizer_fn=None,
                          scope='fc9')
        
        net = tf.squeeze(net, [1,2],name='fc9/squeezed')
        
        return net

# %%
from preprocessing import cifarnet_preprocessing

def load_batch(dataset, batch_size=128, height=image_size, width=image_size, is_training=False):
    """Loads a single batch of data.
    
    Args:
      dataset: The dataset to load.
      batch_size: The number of images in the batch.
      height: The size of each image after preprocessing.
      width: The size of each image after preprocessing.
      is_training: Whether or not we're currently training or evaluating.
    
    Returns:
      images: A Tensor of size [batch_size, height, width, 3], image samples that have been preprocessed.
      images_raw: A Tensor of size [batch_size, height, width, 3], image samples that can be used for visualization.
      labels: A Tensor of size [batch_size], whose values range between 0 and dataset.num_classes.
    """
    
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
        dataset, common_queue_capacity=128,
        common_queue_min=32)
    image_raw, label = data_provider.get(['image', 'label'])
    
    # Preprocess image for usage by Inception.
    image = cifarnet_preprocessing.preprocess_image(image_raw, height, width, is_training=is_training)
    
    # Preprocess the image for display purposes.
    image_raw = tf.expand_dims(image_raw, 0)
    image_raw = tf.image.resize_images(image_raw, [height, width])
    image_raw = tf.squeeze(image_raw)

    # Batch it up.
    images, images_raw, labels = tf.train.batch(
          [image, image_raw, label],
          batch_size=batch_size,
          num_threads=4,
          capacity=4 * batch_size)
    
    return images, images_raw, labels

# %%
# %%time
# This might take a few minutes.

print('Will save model to %s' % train_dir)

with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.INFO)

    dataset = cifar10.get_split('train', cifar10_data_dir)
    images, _, labels = load_batch(dataset)
  
    # Create the model:
    logits =cnn_relu(images, num_classes=dataset.num_classes, is_training=True)
 
    # Specify the loss function:
    one_hot_labels = slim.one_hot_encoding(labels, dataset.num_classes)
    slim.losses.softmax_cross_entropy(logits, one_hot_labels)
    total_loss = slim.losses.get_total_loss()
    
    # Create some summaries to visualize the training process:
    tf.summary.scalar('losses/Total Loss', total_loss)
    
    # Specify the optimizer and create the train op:
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    train_op = slim.learning.create_train_op(total_loss, optimizer)

    # Run the training:
    final_loss = slim.learning.train(
      train_op,
      logdir=train_dir,
      number_of_steps=step, 
          log_every_n_steps=10,
        save_interval_secs=100,
      save_summaries_secs=100)
  
    print('Finished training. Final batch loss %d' % final_loss)
# Out:
# Will save model to /tmp/cifar10/5deep
# WARNING:tensorflow:From <timed exec>:16: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:399: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:152: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# WARNING:tensorflow:From <timed exec>:17: get_total_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_total_loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:262: get_losses (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_losses instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:264: get_regularization_losses (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_regularization_losses instead.
# INFO:tensorflow:Summary name losses/Total Loss is illegal; using losses/Total_Loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/training/python/training/training.py:412: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# INFO:tensorflow:Starting Session.
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Starting Queues.
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Recording summary at step 0.
# INFO:tensorflow:global step 10: loss = 2.3015 (0.224 sec/step)
# INFO:tensorflow:global step 20: loss = 2.3019 (0.217 sec/step)
# INFO:tensorflow:global step 30: loss = 2.3033 (0.209 sec/step)
# INFO:tensorflow:global step 40: loss = 2.3024 (0.220 sec/step)
# INFO:tensorflow:global step 50: loss = 2.3020 (0.239 sec/step)
# INFO:tensorflow:global step 60: loss = 2.3051 (0.223 sec/step)
# INFO:tensorflow:global step 70: loss = 2.3019 (0.211 sec/step)
# INFO:tensorflow:global step 80: loss = 2.3014 (0.213 sec/step)
# INFO:tensorflow:global step 90: loss = 2.3032 (0.218 sec/step)
# INFO:tensorflow:global step 100: loss = 2.3029 (0.225 sec/step)
# INFO:tensorflow:global step 110: loss = 2.3032 (0.215 sec/step)
# INFO:tensorflow:global step 120: loss = 2.3013 (0.225 sec/step)
# INFO:tensorflow:global step 130: loss = 2.3026 (0.230 sec/step)
# INFO:tensorflow:global step 140: loss = 2.3029 (0.223 sec/step)
# INFO:tensorflow:global step 150: loss = 2.3047 (0.223 sec/step)
# INFO:tensorflow:global step 160: loss = 2.3018 (0.239 sec/step)
# INFO:tensorflow:global step 170: loss = 2.3019 (0.220 sec/step)
# INFO:tensorflow:global step 180: loss = 2.3030 (0.220 sec/step)
# INFO:tensorflow:global step 190: loss = 2.3003 (0.211 sec/step)
# INFO:tensorflow:global step 200: loss = 2.3038 (0.208 sec/step)
# INFO:tensorflow:global step 210: loss = 2.3045 (0.229 sec/step)
# INFO:tensorflow:global step 220: loss = 2.3033 (0.210 sec/step)
# INFO:tensorflow:global step 230: loss = 2.3031 (0.213 sec/step)
# INFO:tensorflow:global step 240: loss = 2.3027 (0.224 sec/step)
# INFO:tensorflow:global step 250: loss = 2.3068 (0.228 sec/step)
# INFO:tensorflow:global step 260: loss = 2.3030 (0.242 sec/step)
# INFO:tensorflow:global step 270: loss = 2.3031 (0.226 sec/step)
# INFO:tensorflow:global step 280: loss = 2.3028 (0.227 sec/step)
# INFO:tensorflow:global step 290: loss = 2.3038 (0.223 sec/step)
# INFO:tensorflow:global step 300: loss = 2.3025 (0.229 sec/step)
# INFO:tensorflow:global step 310: loss = 2.3028 (0.221 sec/step)
# INFO:tensorflow:global step 320: loss = 2.3020 (0.205 sec/step)
# INFO:tensorflow:global step 330: loss = 2.3028 (0.216 sec/step)
# INFO:tensorflow:global step 340: loss = 2.3019 (0.215 sec/step)
# INFO:tensorflow:global step 350: loss = 2.3026 (0.224 sec/step)
# INFO:tensorflow:global step 360: loss = 2.3046 (0.215 sec/step)
# INFO:tensorflow:global step 370: loss = 2.3013 (0.229 sec/step)
# INFO:tensorflow:global step 380: loss = 2.3013 (0.215 sec/step)
# INFO:tensorflow:global step 390: loss = 2.3053 (0.230 sec/step)
# INFO:tensorflow:global step 400: loss = 2.3022 (0.228 sec/step)
# INFO:tensorflow:global step 410: loss = 2.3038 (0.207 sec/step)
# INFO:tensorflow:global step 420: loss = 2.3030 (0.224 sec/step)
# INFO:tensorflow:global step 430: loss = 2.3025 (0.223 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:global_step/sec: 4.38539
# INFO:tensorflow:Recording summary at step 438.
# INFO:tensorflow:global step 440: loss = 2.3028 (0.224 sec/step)
# INFO:tensorflow:global step 450: loss = 2.3020 (0.231 sec/step)
# INFO:tensorflow:global step 460: loss = 2.3021 (0.222 sec/step)
# INFO:tensorflow:global step 470: loss = 2.3019 (0.226 sec/step)
# INFO:tensorflow:global step 480: loss = 2.3061 (0.217 sec/step)
# INFO:tensorflow:global step 490: loss = 2.3024 (0.208 sec/step)
# INFO:tensorflow:global step 500: loss = 2.3027 (0.215 sec/step)
# INFO:tensorflow:global step 510: loss = 2.3016 (0.237 sec/step)
# INFO:tensorflow:global step 520: loss = 2.3033 (0.202 sec/step)
# INFO:tensorflow:global step 930: loss = 2.3030 (0.226 sec/step)
# INFO:tensorflow:global step 940: loss = 2.3020 (0.214 sec/step)
# INFO:tensorflow:global step 950: loss = 2.3022 (0.230 sec/step)
# INFO:tensorflow:global step 960: loss = 2.3013 (0.226 sec/step)
# INFO:tensorflow:global step 970: loss = 2.3022 (0.221 sec/step)
# INFO:tensorflow:global step 980: loss = 2.3033 (0.217 sec/step)
# INFO:tensorflow:global step 990: loss = 2.3032 (0.232 sec/step)
# INFO:tensorflow:global step 1000: loss = 2.3022 (0.211 sec/step)
# INFO:tensorflow:global step 1010: loss = 2.3026 (0.232 sec/step)
# INFO:tensorflow:global step 1020: loss = 2.3043 (0.222 sec/step)
# INFO:tensorflow:global step 1030: loss = 2.3014 (0.208 sec/step)
# INFO:tensorflow:global step 1040: loss = 2.3032 (0.226 sec/step)
# INFO:tensorflow:global step 1050: loss = 2.3036 (0.214 sec/step)
# INFO:tensorflow:global step 1060: loss = 2.3004 (0.213 sec/step)
# INFO:tensorflow:global step 1070: loss = 2.3023 (0.218 sec/step)
# INFO:tensorflow:global step 1080: loss = 2.3023 (0.213 sec/step)
# INFO:tensorflow:global step 1090: loss = 2.3028 (0.217 sec/step)
# INFO:tensorflow:global step 1100: loss = 2.3031 (0.229 sec/step)
# INFO:tensorflow:global step 1110: loss = 2.3032 (0.215 sec/step)
# INFO:tensorflow:global step 1120: loss = 2.3028 (0.234 sec/step)
# INFO:tensorflow:global step 1130: loss = 2.3019 (0.232 sec/step)
# INFO:tensorflow:global step 1140: loss = 2.3022 (0.222 sec/step)
# INFO:tensorflow:global step 1150: loss = 2.3010 (0.204 sec/step)
# INFO:tensorflow:global step 1160: loss = 2.3037 (0.222 sec/step)
# INFO:tensorflow:global step 1170: loss = 2.3037 (0.225 sec/step)
# INFO:tensorflow:global step 1180: loss = 2.3024 (0.238 sec/step)
# INFO:tensorflow:global step 1190: loss = 2.3034 (0.212 sec/step)
# INFO:tensorflow:global step 1200: loss = 2.3021 (0.222 sec/step)
# INFO:tensorflow:global step 1210: loss = 2.3036 (0.227 sec/step)
# INFO:tensorflow:global step 1220: loss = 2.3032 (0.229 sec/step)
# INFO:tensorflow:global step 1230: loss = 2.3041 (0.219 sec/step)
# INFO:tensorflow:global step 1240: loss = 2.3038 (0.233 sec/step)
# INFO:tensorflow:global step 1250: loss = 2.3040 (0.224 sec/step)
# INFO:tensorflow:global step 1260: loss = 2.3021 (0.214 sec/step)
# INFO:tensorflow:global step 1270: loss = 2.3011 (0.220 sec/step)
# INFO:tensorflow:global step 1280: loss = 2.3024 (0.224 sec/step)
# INFO:tensorflow:global step 1290: loss = 2.3030 (0.214 sec/step)
# INFO:tensorflow:global step 1300: loss = 2.3009 (0.219 sec/step)
# INFO:tensorflow:global step 1310: loss = 2.3019 (0.236 sec/step)
# INFO:tensorflow:global step 1320: loss = 2.3041 (0.229 sec/step)
# INFO:tensorflow:global step 1330: loss = 2.3022 (0.233 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10
# INFO:tensorflow:global step 2940: loss = 2.3034 (0.251 sec/step)
# INFO:tensorflow:global step 2950: loss = 2.3027 (0.234 sec/step)
# INFO:tensorflow:global step 2960: loss = 2.3028 (0.246 sec/step)
# INFO:tensorflow:global step 2970: loss = 2.3043 (0.209 sec/step)
# INFO:tensorflow:global step 2980: loss = 2.3029 (0.219 sec/step)
# INFO:tensorflow:global step 2990: loss = 2.3039 (0.209 sec/step)
# INFO:tensorflow:global step 3000: loss = 2.3031 (0.222 sec/step)
# INFO:tensorflow:global step 3010: loss = 2.3051 (0.220 sec/step)
# INFO:tensorflow:global step 3020: loss = 2.3030 (0.215 sec/step)
# INFO:tensorflow:global step 3030: loss = 2.3024 (0.225 sec/step)
# INFO:tensorflow:global step 3040: loss = 2.3026 (0.209 sec/step)
# INFO:tensorflow:global step 3050: loss = 2.3033 (0.236 sec/step)
# INFO:tensorflow:global step 3060: loss = 2.3034 (0.219 sec/step)
# INFO:tensorflow:global step 3070: loss = 2.3022 (0.230 sec/step)
# INFO:tensorflow:global step 3080: loss = 2.3030 (0.216 sec/step)
# INFO:tensorflow:global step 3090: loss = 2.3046 (0.220 sec/step)
# INFO:tensorflow:global step 3100: loss = 2.3030 (0.234 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:global_step/sec: 4.45001
# INFO:tensorflow:Recording summary at step 3108.
# INFO:tensorflow:global step 3110: loss = 2.3042 (0.298 sec/step)
# INFO:tensorflow:global step 3120: loss = 2.3039 (0.211 sec/step)
# INFO:tensorflow:global step 3130: loss = 2.3033 (0.225 sec/step)
# INFO:tensorflow:global step 3140: loss = 2.3028 (0.221 sec/step)
# INFO:tensorflow:global step 3150: loss = 2.3034 (0.221 sec/step)
# INFO:tensorflow:global step 3160: loss = 2.3024 (0.208 sec/step)
# INFO:tensorflow:global step 3170: loss = 2.3035 (0.217 sec/step)
# INFO:tensorflow:global step 3180: loss = 2.3018 (0.237 sec/step)
# INFO:tensorflow:global step 3190: loss = 2.3019 (0.223 sec/step)
# INFO:tensorflow:global step 3200: loss = 2.3029 (0.230 sec/step)
# INFO:tensorflow:global step 3210: loss = 2.3032 (0.224 sec/step)
# INFO:tensorflow:global step 3220: loss = 2.3012 (0.214 sec/step)
# INFO:tensorflow:global step 3230: loss = 2.3029 (0.231 sec/step)
# INFO:tensorflow:global step 3240: loss = 2.3047 (0.222 sec/step)
# INFO:tensorflow:global step 3250: loss = 2.3023 (0.216 sec/step)
# INFO:tensorflow:global step 3260: loss = 2.3057 (0.235 sec/step)
# INFO:tensorflow:global step 3270: loss = 2.3028 (0.223 sec/step)
# INFO:tensorflow:global step 3280: loss = 2.3030 (0.210 sec/step)
# INFO:tensorflow:global step 3290: loss = 2.3026 (0.228 sec/step)
# INFO:tensorflow:global step 3300: loss = 2.3028 (0.213 sec/step)
# INFO:tensorflow:global step 3310: loss = 2.3018 (0.215 sec/step)
# INFO:tensorflow:global step 3320: loss = 2.3014 (0.226 sec/step)
# INFO:tensorflow:global step 3330: loss = 2.3041 (0.237 sec/step)
# INFO:tensorflow:global step 3340: loss = 2.3021 (0.229 sec/step)
# INFO:tensorflow:global step 3350: loss = 2.3035 (0.207 sec/step)
# INFO:tensorflow:global step 3360: loss = 2.3038 (0.213 sec/step)
# INFO:tensorflow:global step 3370: loss = 2.3045 (0.240 sec/step)
# INFO:tensorflow:global step 3380: loss = 2.3026 (0.240 sec/step)
# INFO:tensorflow:global step 3390: loss = 2.3034 (0.250 sec/step)
# INFO:tensorflow:global step 3400: loss = 2.3038 (0.219 sec/step)
# INFO:tensorflow:global step 3410: loss = 2.3023 (0.236 sec/step)
# INFO:tensorflow:global step 3420: loss = 2.3018 (0.221 sec/step)
# INFO:tensorflow:global step 3430: loss = 2.3037 (0.228 sec/step)
# INFO:tensorflow:global step 3440: loss = 2.3026 (0.222 sec/step)
# INFO:tensorflow:global step 3450: loss = 2.3019 (0.239 sec/step)
# INFO:tensorflow:global step 3460: loss = 2.3019 (0.239 sec/step)
# INFO:tensorflow:global step 3470: loss = 2.3022 (0.228 sec/step)
# INFO:tensorflow:global step 3480: loss = 2.3031 (0.228 sec/step)
# INFO:tensorflow:global step 3490: loss = 2.3039 (0.230 sec/step)
# INFO:tensorflow:global step 3500: loss = 2.3052 (0.224 sec/step)
# INFO:tensorflow:global step 3510: loss = 2.3024 (0.223 sec/step)
# INFO:tensorflow:global step 3520: loss = 2.3018 (0.220 sec/step)
# INFO:tensorflow:global step 3530: loss = 2.3046 (0.240 sec/step)
# INFO:tensorflow:global step 3540: loss = 2.3030 (0.217 sec/step)
# INFO:tensorflow:global step 3550: loss = 2.3024 (0.238 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:global_step/sec: 4.42999
# INFO:tensorflow:Recording summary at step 3552.
# INFO:tensorflow:global step 3560: loss = 2.3016 (0.229 sec/step)
# INFO:tensorflow:global step 3570: loss = 2.3036 (0.216 sec/step)
# INFO:tensorflow:global step 3580: loss = 2.3021 (0.226 sec/step)
# INFO:tensorflow:global step 3590: loss = 2.3035 (0.221 sec/step)
# INFO:tensorflow:global step 3600: loss = 2.3040 (0.224 sec/step)
# INFO:tensorflow:global step 3610: loss = 2.3025 (0.226 sec/step)
# INFO:tensorflow:global step 3620: loss = 2.3026 (0.229 sec/step)
# INFO:tensorflow:global step 3630: loss = 2.3025 (0.223 sec/step)
# INFO:tensorflow:global step 3640: loss = 2.3053 (0.225 sec/step)
# INFO:tensorflow:global step 3650: loss = 2.3019 (0.229 sec/step)
# INFO:tensorflow:global step 3660: loss = 2.3038 (0.209 sec/step)
# INFO:tensorflow:global step 3670: loss = 2.3032 (0.228 sec/step)
# INFO:tensorflow:global step 3680: loss = 2.3024 (0.240 sec/step)
# INFO:tensorflow:global step 3690: loss = 2.3015 (0.214 sec/step)
# INFO:tensorflow:global step 3700: loss = 2.3033 (0.250 sec/step)
# INFO:tensorflow:global step 3710: loss = 2.3010 (0.239 sec/step)
# INFO:tensorflow:global step 3720: loss = 2.3039 (0.219 sec/step)
# INFO:tensorflow:global step 3730: loss = 2.3016 (0.213 sec/step)
# INFO:tensorflow:global step 3740: loss = 2.3050 (0.243 sec/step)
# INFO:tensorflow:global step 3750: loss = 2.3029 (0.236 sec/step)
# INFO:tensorflow:global step 3760: loss = 2.3042 (0.228 sec/step)
# INFO:tensorflow:global step 3770: loss = 2.3038 (0.217 sec/step)
# INFO:tensorflow:global step 3780: loss = 2.3025 (0.212 sec/step)
# INFO:tensorflow:global step 3790: loss = 2.3011 (0.240 sec/step)
# INFO:tensorflow:global step 3800: loss = 2.3003 (0.221 sec/step)
# INFO:tensorflow:global step 3810: loss = 2.3022 (0.229 sec/step)
# INFO:tensorflow:global step 3820: loss = 2.3047 (0.224 sec/step)
# INFO:tensorflow:global step 3830: loss = 2.3036 (0.216 sec/step)
# INFO:tensorflow:global step 3840: loss = 2.3022 (0.227 sec/step)
# INFO:tensorflow:global step 3850: loss = 2.3021 (0.218 sec/step)
# INFO:tensorflow:global step 3860: loss = 2.3012 (0.214 sec/step)
# INFO:tensorflow:global step 3870: loss = 2.3036 (0.222 sec/step)
# INFO:tensorflow:global step 3880: loss = 2.3037 (0.215 sec/step)
# INFO:tensorflow:global step 3890: loss = 2.3044 (0.211 sec/step)
# INFO:tensorflow:global step 3900: loss = 2.3025 (0.218 sec/step)
# INFO:tensorflow:global step 3910: loss = 2.3012 (0.231 sec/step)
# INFO:tensorflow:global step 3920: loss = 2.3047 (0.230 sec/step)
# INFO:tensorflow:global step 3930: loss = 2.3047 (0.253 sec/step)
# INFO:tensorflow:global step 3940: loss = 2.3018 (0.243 sec/step)
# INFO:tensorflow:global step 3950: loss = 2.3067 (0.208 sec/step)
# INFO:tensorflow:global step 3960: loss = 2.3020 (0.216 sec/step)
# INFO:tensorflow:global step 3970: loss = 2.3020 (0.226 sec/step)
# INFO:tensorflow:global step 3980: loss = 2.3039 (0.212 sec/step)
# INFO:tensorflow:global step 3990: loss = 2.3041 (0.230 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:global_step/sec: 4.43001
# INFO:tensorflow:Recording summary at step 3994.
# INFO:tensorflow:global step 4000: loss = 2.3032 (0.209 sec/step)
# INFO:tensorflow:global step 4010: loss = 2.3043 (0.236 sec/step)
# INFO:tensorflow:global step 4020: loss = 2.3015 (0.205 sec/step)
# INFO:tensorflow:global step 4030: loss = 2.3023 (0.217 sec/step)
# INFO:tensorflow:global step 4040: loss = 2.3040 (0.231 sec/step)
# INFO:tensorflow:global step 4050: loss = 2.3024 (0.222 sec/step)
# INFO:tensorflow:global step 4060: loss = 2.3022 (0.230 sec/step)
# INFO:tensorflow:global step 4070: loss = 2.3020 (0.228 sec/step)
# INFO:tensorflow:global step 4080: loss = 2.3033 (0.223 sec/step)
# INFO:tensorflow:global step 4090: loss = 2.3043 (0.209 sec/step)
# INFO:tensorflow:global step 4100: loss = 2.3030 (0.214 sec/step)
# INFO:tensorflow:global step 4110: loss = 2.3029 (0.226 sec/step)
# INFO:tensorflow:global step 4120: loss = 2.3025 (0.213 sec/step)
# INFO:tensorflow:global step 4130: loss = 2.3024 (0.219 sec/step)
# INFO:tensorflow:global step 4140: loss = 2.3029 (0.215 sec/step)
# INFO:tensorflow:global step 4150: loss = 2.3034 (0.223 sec/step)
# INFO:tensorflow:global step 4160: loss = 2.3034 (0.217 sec/step)
# INFO:tensorflow:global step 4170: loss = 2.3022 (0.216 sec/step)
# INFO:tensorflow:global step 4180: loss = 2.3045 (0.206 sec/step)
# INFO:tensorflow:global step 4190: loss = 2.3022 (0.226 sec/step)
# INFO:tensorflow:global step 4200: loss = 2.3030 (0.226 sec/step)
# INFO:tensorflow:global step 4210: loss = 2.3047 (0.235 sec/step)
# INFO:tensorflow:global step 4220: loss = 2.3030 (0.218 sec/step)
# INFO:tensorflow:global step 4230: loss = 2.3028 (0.236 sec/step)
# INFO:tensorflow:global step 4240: loss = 2.3023 (0.235 sec/step)
# INFO:tensorflow:global step 4250: loss = 2.3018 (0.226 sec/step)
# INFO:tensorflow:global step 4260: loss = 2.3046 (0.228 sec/step)
# INFO:tensorflow:global step 4270: loss = 2.3030 (0.227 sec/step)
# INFO:tensorflow:global step 4280: loss = 2.3041 (0.223 sec/step)
# INFO:tensorflow:global step 4290: loss = 2.3020 (0.225 sec/step)
# INFO:tensorflow:global step 4300: loss = 2.3015 (0.229 sec/step)
# INFO:tensorflow:global step 4310: loss = 2.3033 (0.211 sec/step)
# INFO:tensorflow:global step 4320: loss = 2.3052 (0.227 sec/step)
# INFO:tensorflow:global step 4330: loss = 2.3016 (0.206 sec/step)
# INFO:tensorflow:global step 4340: loss = 2.3058 (0.213 sec/step)
# INFO:tensorflow:global step 4350: loss = 2.3020 (0.208 sec/step)
# INFO:tensorflow:global step 4360: loss = 2.3021 (0.218 sec/step)
# INFO:tensorflow:global step 4370: loss = 2.3031 (0.253 sec/step)
# INFO:tensorflow:global step 4380: loss = 2.3028 (0.219 sec/step)
# INFO:tensorflow:global step 4390: loss = 2.3035 (0.218 sec/step)
# INFO:tensorflow:global step 4400: loss = 2.3056 (0.228 sec/step)
# INFO:tensorflow:global step 4410: loss = 2.3034 (0.226 sec/step)
# INFO:tensorflow:global step 4420: loss = 2.3007 (0.209 sec/step)
# INFO:tensorflow:global step 4430: loss = 2.3059 (0.219 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:global step 4440: loss = 2.3026 (0.259 sec/step)
# INFO:tensorflow:Recording summary at step 4440.
# INFO:tensorflow:global step 4450: loss = 2.3025 (0.214 sec/step)
# INFO:tensorflow:global step 4460: loss = 2.3041 (0.241 sec/step)
# INFO:tensorflow:global step 4470: loss = 2.3030 (0.210 sec/step)
# INFO:tensorflow:global step 4480: loss = 2.3050 (0.242 sec/step)
# INFO:tensorflow:global step 4490: loss = 2.3044 (0.231 sec/step)
# INFO:tensorflow:global step 4500: loss = 2.3046 (0.247 sec/step)
# INFO:tensorflow:global step 4510: loss = 2.3024 (0.217 sec/step)
# INFO:tensorflow:global step 4520: loss = 2.3032 (0.213 sec/step)
# INFO:tensorflow:global step 4530: loss = 2.3030 (0.215 sec/step)
# INFO:tensorflow:global step 4540: loss = 2.3028 (0.240 sec/step)
# INFO:tensorflow:global step 4550: loss = 2.3031 (0.220 sec/step)
# INFO:tensorflow:global step 4560: loss = 2.3039 (0.226 sec/step)
# INFO:tensorflow:global step 4570: loss = 2.3028 (0.217 sec/step)
# INFO:tensorflow:global step 4580: loss = 2.3028 (0.221 sec/step)
# INFO:tensorflow:global step 4590: loss = 2.3046 (0.222 sec/step)
# INFO:tensorflow:global step 4600: loss = 2.3027 (0.239 sec/step)
# INFO:tensorflow:global step 4610: loss = 2.3039 (0.228 sec/step)
# INFO:tensorflow:global step 4620: loss = 2.3033 (0.218 sec/step)
# INFO:tensorflow:global step 4630: loss = 2.3022 (0.231 sec/step)
# INFO:tensorflow:global step 4640: loss = 2.3021 (0.223 sec/step)
# INFO:tensorflow:global step 4650: loss = 2.3032 (0.217 sec/step)
# INFO:tensorflow:global step 4660: loss = 2.3029 (0.226 sec/step)
# INFO:tensorflow:global step 4670: loss = 2.3046 (0.224 sec/step)
# INFO:tensorflow:global step 4680: loss = 2.3032 (0.218 sec/step)
# INFO:tensorflow:global step 4690: loss = 2.3033 (0.208 sec/step)
# INFO:tensorflow:global step 4700: loss = 2.3010 (0.215 sec/step)
# INFO:tensorflow:global step 4710: loss = 2.3041 (0.221 sec/step)
# INFO:tensorflow:global step 4720: loss = 2.3024 (0.218 sec/step)
# INFO:tensorflow:global step 4730: loss = 2.3048 (0.233 sec/step)
# INFO:tensorflow:global step 4740: loss = 2.3027 (0.235 sec/step)
# INFO:tensorflow:global step 4750: loss = 2.3032 (0.236 sec/step)
# INFO:tensorflow:global step 4760: loss = 2.3027 (0.222 sec/step)
# INFO:tensorflow:global step 4770: loss = 2.3015 (0.226 sec/step)
# INFO:tensorflow:global step 4780: loss = 2.3032 (0.232 sec/step)
# INFO:tensorflow:global step 4790: loss = 2.3040 (0.229 sec/step)
# INFO:tensorflow:global step 4800: loss = 2.3016 (0.209 sec/step)
# INFO:tensorflow:global step 4810: loss = 2.3021 (0.245 sec/step)
# INFO:tensorflow:global step 4820: loss = 2.3024 (0.216 sec/step)
# INFO:tensorflow:global step 4830: loss = 2.3047 (0.217 sec/step)
# INFO:tensorflow:global step 4840: loss = 2.3019 (0.229 sec/step)
# INFO:tensorflow:global step 4850: loss = 2.3026 (0.223 sec/step)
# INFO:tensorflow:global step 4860: loss = 2.3042 (0.210 sec/step)
# INFO:tensorflow:global step 4870: loss = 2.3049 (0.231 sec/step)
# INFO:tensorflow:global step 4880: loss = 2.3025 (0.222 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Recording summary at step 4882.
# INFO:tensorflow:global step 4890: loss = 2.3040 (0.220 sec/step)
# INFO:tensorflow:global step 4900: loss = 2.3030 (0.223 sec/step)
# INFO:tensorflow:global step 4910: loss = 2.3016 (0.226 sec/step)
# INFO:tensorflow:global step 4920: loss = 2.3029 (0.226 sec/step)
# INFO:tensorflow:global step 4930: loss = 2.3047 (0.224 sec/step)
sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Recording summary at step 5768.
# INFO:tensorflow:global step 5770: loss = 2.3035 (0.251 sec/step)
# INFO:tensorflow:global step 5780: loss = 2.3022 (0.237 sec/step)
# INFO:tensorflow:global step 5790: loss = 2.3021 (0.224 sec/step)
# INFO:tensorflow:global step 5800: loss = 2.3028 (0.219 sec/step)
# INFO:tensorflow:global step 5810: loss = 2.3023 (0.221 sec/step)
# INFO:tensorflow:global step 5820: loss = 2.3023 (0.224 sec/step)
# INFO:tensorflow:global step 5830: loss = 2.3026 (0.210 sec/step)
# INFO:tensorflow:global step 5840: loss = 2.3037 (0.216 sec/step)
# INFO:tensorflow:global step 5850: loss = 2.3025 (0.229 sec/step)
# INFO:tensorflow:global step 5860: loss = 2.3034 (0.226 sec/step)
# INFO:tensorflow:global step 5870: loss = 2.3003 (0.230 sec/step)
# INFO:tensorflow:global step 5880: loss = 2.3030 (0.212 sec/step)
# INFO:tensorflow:global step 5890: loss = 2.3020 (0.218 sec/step)
# INFO:tensorflow:global step 5900: loss = 2.3023 (0.237 sec/step)
# INFO:tensorflow:global step 5910: loss = 2.3034 (0.210 sec/step)
# INFO:tensorflow:global step 5920: loss = 2.3035 (0.233 sec/step)
# INFO:tensorflow:global step 5930: loss = 2.3031 (0.227 sec/step)
# INFO:tensorflow:global step 5940: loss = 2.3032 (0.223 sec/step)
# INFO:tensorflow:global step 5950: loss = 2.3037 (0.225 sec/step)
# INFO:tensorflow:global step 5960: loss = 2.3025 (0.220 sec/step)
# INFO:tensorflow:global step 5970: loss = 2.3004 (0.209 sec/step)
# INFO:tensorflow:global step 5980: loss = 2.3018 (0.218 sec/step)
# INFO:tensorflow:global step 5990: loss = 2.3013 (0.232 sec/step)
# INFO:tensorflow:global step 6000: loss = 2.3017 (0.215 sec/step)
# INFO:tensorflow:global step 6010: loss = 2.3024 (0.220 sec/step)
# INFO:tensorflow:global step 6020: loss = 2.3039 (0.214 sec/step)
# INFO:tensorflow:global step 6030: loss = 2.3020 (0.216 sec/step)
# INFO:tensorflow:global step 6040: loss = 2.3038 (0.235 sec/step)
# INFO:tensorflow:global step 6050: loss = 2.3021 (0.223 sec/step)
# INFO:tensorflow:global step 6060: loss = 2.3038 (0.235 sec/step)
# INFO:tensorflow:global step 6070: loss = 2.3027 (0.227 sec/step)
# INFO:tensorflow:global step 6080: loss = 2.3028 (0.226 sec/step)
# INFO:tensorflow:global step 6090: loss = 2.3031 (0.208 sec/step)
# INFO:tensorflow:global step 6100: loss = 2.3026 (0.226 sec/step)
# INFO:tensorflow:global step 6110: loss = 2.3041 (0.226 sec/step)
# INFO:tensorflow:global step 6120: loss = 2.3026 (0.218 sec/step)
# INFO:tensorflow:global step 6130: loss = 2.3023 (0.228 sec/step)
# INFO:tensorflow:global step 6140: loss = 2.3019 (0.211 sec/step)
# INFO:tensorflow:global step 6150: loss = 2.3021 (0.227 sec/step)
# INFO:tensorflow:global step 6160: loss = 2.3027 (0.217 sec/step)
# INFO:tensorflow:global step 6170: loss = 2.3024 (0.219 sec/step)
# INFO:tensorflow:global step 6180: loss = 2.3032 (0.209 sec/step)
# INFO:tensorflow:global step 6190: loss = 2.3030 (0.225 sec/step)
# INFO:tensorflow:global step 6200: loss = 2.3019 (0.217 sec/step)
# INFO:tensorflow:global step 6210: loss = 2.3035 (0.212 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Recording summary at step 6212.
# INFO:tensorflow:global step 6220: loss = 2.3009 (0.226 sec/step)
# INFO:tensorflow:global step 6230: loss = 2.3027 (0.210 sec/step)
# INFO:tensorflow:global step 6240: loss = 2.3017 (0.246 sec/step)
# INFO:tensorflow:global step 6250: loss = 2.3039 (0.218 sec/step)
# INFO:tensorflow:global step 6260: loss = 2.3022 (0.236 sec/step)
# INFO:tensorflow:global step 6270: loss = 2.3029 (0.207 sec/step)
# INFO:tensorflow:global step 6280: loss = 2.3034 (0.221 sec/step)
# INFO:tensorflow:global step 6290: loss = 2.3033 (0.220 sec/step)
# INFO:tensorflow:global step 6300: loss = 2.3024 (0.216 sec/step)
# INFO:tensorflow:global step 6310: loss = 2.3022 (0.213 sec/step)
# INFO:tensorflow:global step 6320: loss = 2.3026 (0.221 sec/step)
# INFO:tensorflow:global step 6330: loss = 2.3031 (0.237 sec/step)
# INFO:tensorflow:global step 6340: loss = 2.3028 (0.225 sec/step)
# INFO:tensorflow:global step 6350: loss = 2.3030 (0.255 sec/step)
# INFO:tensorflow:global step 6360: loss = 2.3019 (0.228 sec/step)
# INFO:tensorflow:global step 6370: loss = 2.3029 (0.217 sec/step)
# INFO:tensorflow:global step 6380: loss = 2.3024 (0.217 sec/step)
# INFO:tensorflow:global step 6390: loss = 2.3027 (0.237 sec/step)
# INFO:tensorflow:global step 6400: loss = 2.3006 (0.231 sec/step)
# INFO:tensorflow:global step 6410: loss = 2.3028 (0.239 sec/step)
# INFO:tensorflow:global step 6420: loss = 2.3044 (0.221 sec/step)
# INFO:tensorflow:global step 6430: loss = 2.3048 (0.230 sec/step)
# INFO:tensorflow:global step 6440: loss = 2.3016 (0.215 sec/step)
# INFO:tensorflow:global step 6450: loss = 2.3023 (0.230 sec/step)
# INFO:tensorflow:global step 6460: loss = 2.3034 (0.216 sec/step)
# INFO:tensorflow:global step 6470: loss = 2.3027 (0.232 sec/step)
# INFO:tensorflow:global step 6480: loss = 2.3046 (0.220 sec/step)
# INFO:tensorflow:global step 6490: loss = 2.3039 (0.219 sec/step)
# INFO:tensorflow:global step 6500: loss = 2.3055 (0.242 sec/step)
# INFO:tensorflow:global step 6510: loss = 2.3032 (0.220 sec/step)
# INFO:tensorflow:global step 6520: loss = 2.3029 (0.215 sec/step)
# INFO:tensorflow:global step 6530: loss = 2.3026 (0.228 sec/step)
# INFO:tensorflow:global step 6540: loss = 2.3045 (0.234 sec/step)
# INFO:tensorflow:global step 6550: loss = 2.3022 (0.213 sec/step)
# INFO:tensorflow:global step 6560: loss = 2.3024 (0.217 sec/step)
# INFO:tensorflow:global step 18050: loss = 2.3026 (0.225 sec/step)
# INFO:tensorflow:global step 18060: loss = 2.3028 (0.216 sec/step)
# INFO:tensorflow:global step 18070: loss = 2.3038 (0.224 sec/step)
# INFO:tensorflow:global step 18080: loss = 2.3028 (0.233 sec/step)
# INFO:tensorflow:global step 18090: loss = 2.3023 (0.222 sec/step)
# INFO:tensorflow:global step 18100: loss = 2.3031 (0.225 sec/step)
# INFO:tensorflow:global step 18110: loss = 2.3021 (0.203 sec/step)
# INFO:tensorflow:global step 18120: loss = 2.3033 (0.230 sec/step)
# INFO:tensorflow:global step 18130: loss = 2.3022 (0.218 sec/step)
# INFO:tensorflow:global step 18140: loss = 2.3032 (0.218 sec/step)
# INFO:tensorflow:global step 18150: loss = 2.3020 (0.213 sec/step)
# INFO:tensorflow:global step 18160: loss = 2.3032 (0.208 sec/step)
# INFO:tensorflow:global step 18170: loss = 2.3023 (0.209 sec/step)
# INFO:tensorflow:global step 18180: loss = 2.3026 (0.229 sec/step)
# INFO:tensorflow:global step 18190: loss = 2.3028 (0.229 sec/step)
# INFO:tensorflow:global step 18200: loss = 2.3024 (0.228 sec/step)
# INFO:tensorflow:global step 18210: loss = 2.3031 (0.240 sec/step)
# INFO:tensorflow:global step 18220: loss = 2.3024 (0.217 sec/step)
# INFO:tensorflow:global step 18230: loss = 2.3022 (0.209 sec/step)
# INFO:tensorflow:global step 18240: loss = 2.3035 (0.223 sec/step)
# INFO:tensorflow:global step 18250: loss = 2.3032 (0.224 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Recording summary at step 18259.
# INFO:tensorflow:global step 18260: loss = 2.3028 (0.344 sec/step)
# INFO:tensorflow:global step 18270: loss = 2.3018 (0.224 sec/step)
# INFO:tensorflow:global step 18280: loss = 2.3020 (0.225 sec/step)
# INFO:tensorflow:global step 18290: loss = 2.3027 (0.228 sec/step)
# INFO:tensorflow:global step 18300: loss = 2.3032 (0.214 sec/step)
# INFO:tensorflow:global step 18310: loss = 2.3034 (0.222 sec/step)
# INFO:tensorflow:global step 18320: loss = 2.3022 (0.220 sec/step)
# INFO:tensorflow:global step 18330: loss = 2.3019 (0.250 sec/step)
# INFO:tensorflow:global step 18340: loss = 2.3025 (0.206 sec/step)
# INFO:tensorflow:global step 18350: loss = 2.3028 (0.212 sec/step)
# INFO:tensorflow:global step 18360: loss = 2.3020 (0.217 sec/step)
# INFO:tensorflow:global step 18370: loss = 2.3034 (0.217 sec/step)
# INFO:tensorflow:global step 18380: loss = 2.3032 (0.208 sec/step)
# INFO:tensorflow:global step 18390: loss = 2.3022 (0.209 sec/step)
# INFO:tensorflow:global step 18400: loss = 2.3024 (0.215 sec/step)
# INFO:tensorflow:global step 18410: loss = 2.3034 (0.221 sec/step)
# INFO:tensorflow:global step 18420: loss = 2.3031 (0.207 sec/step)
# INFO:tensorflow:global step 18430: loss = 2.3032 (0.206 sec/step)
# INFO:tensorflow:global step 18440: loss = 2.3032 (0.213 sec/step)
# INFO:tensorflow:global step 18450: loss = 2.3027 (0.225 sec/step)
# INFO:tensorflow:global step 18460: loss = 2.3033 (0.234 sec/step)
# INFO:tensorflow:global step 18470: loss = 2.3042 (0.244 sec/step)
# INFO:tensorflow:global step 18480: loss = 2.3026 (0.209 sec/step)
# INFO:tensorflow:global step 18490: loss = 2.3029 (0.214 sec/step)
# INFO:tensorflow:global step 18500: loss = 2.3028 (0.219 sec/step)
# INFO:tensorflow:global step 18510: loss = 2.3029 (0.242 sec/step)
# INFO:tensorflow:global step 18520: loss = 2.3027 (0.217 sec/step)
# INFO:tensorflow:global step 18530: loss = 2.3034 (0.227 sec/step)
# INFO:tensorflow:global step 18540: loss = 2.3022 (0.223 sec/step)
# INFO:tensorflow:global step 18550: loss = 2.3032 (0.224 sec/step)
# INFO:tensorflow:global step 18560: loss = 2.3025 (0.228 sec/step)
# INFO:tensorflow:global step 18570: loss = 2.3029 (0.218 sec/step)
# INFO:tensorflow:global step 18580: loss = 2.3016 (0.216 sec/step)
# INFO:tensorflow:global step 18590: loss = 2.3022 (0.219 sec/step)
# INFO:tensorflow:global step 18600: loss = 2.3026 (0.219 sec/step)
# INFO:tensorflow:global step 18610: loss = 2.3011 (0.218 sec/step)
# INFO:tensorflow:global step 18620: loss = 2.3031 (0.227 sec/step)
# INFO:tensorflow:global step 18630: loss = 2.3027 (0.209 sec/step)
# INFO:tensorflow:global step 18640: loss = 2.3025 (0.229 sec/step)
# INFO:tensorflow:global step 18650: loss = 2.3025 (0.250 sec/step)
# INFO:tensorflow:global step 18660: loss = 2.3031 (0.213 sec/step)
# INFO:tensorflow:global step 18670: loss = 2.3027 (0.205 sec/step)
# INFO:tensorflow:global step 18680: loss = 2.3025 (0.214 sec/step)
# INFO:tensorflow:global step 18690: loss = 2.3030 (0.240 sec/step)
# INFO:tensorflow:global step 18700: loss = 2.3024 (0.213 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Recording summary at step 18707.
# INFO:tensorflow:global step 18710: loss = 2.3026 (0.282 sec/step)
# INFO:tensorflow:global step 18720: loss = 2.3015 (0.223 sec/step)
# INFO:tensorflow:global step 18730: loss = 2.3027 (0.222 sec/step)
# INFO:tensorflow:global step 18740: loss = 2.3027 (0.233 sec/step)
# INFO:tensorflow:global step 18750: loss = 2.3024 (0.221 sec/step)
# INFO:tensorflow:global step 18760: loss = 2.3040 (0.214 sec/step)
# INFO:tensorflow:global step 18770: loss = 2.3021 (0.213 sec/step)
# INFO:tensorflow:global step 18780: loss = 2.3025 (0.217 sec/step)
# INFO:tensorflow:global step 18790: loss = 2.3032 (0.229 sec/step)
# INFO:tensorflow:global step 18800: loss = 2.3026 (0.220 sec/step)
# INFO:tensorflow:global step 18810: loss = 2.3024 (0.216 sec/step)
# INFO:tensorflow:global step 18820: loss = 2.3028 (0.205 sec/step)
# INFO:tensorflow:global step 18830: loss = 2.3025 (0.214 sec/step)
# INFO:tensorflow:global step 18840: loss = 2.3023 (0.223 sec/step)
# INFO:tensorflow:global step 18850: loss = 2.3026 (0.213 sec/step)
# INFO:tensorflow:global step 18860: loss = 2.3031 (0.214 sec/step)
# INFO:tensorflow:global step 18870: loss = 2.3025 (0.221 sec/step)
# INFO:tensorflow:global step 18880: loss = 2.3028 (0.216 sec/step)
# INFO:tensorflow:global step 18890: loss = 2.3023 (0.214 sec/step)
# INFO:tensorflow:global step 18900: loss = 2.3032 (0.218 sec/step)
# INFO:tensorflow:global step 18910: loss = 2.3024 (0.230 sec/step)
# INFO:tensorflow:global step 18920: loss = 2.3034 (0.233 sec/step)
# INFO:tensorflow:global step 18930: loss = 2.3029 (0.209 sec/step)
# INFO:tensorflow:global step 18940: loss = 2.3030 (0.201 sec/step)
# INFO:tensorflow:global step 18950: loss = 2.3025 (0.205 sec/step)
# INFO:tensorflow:global step 18960: loss = 2.3034 (0.217 sec/step)
# INFO:tensorflow:global step 18970: loss = 2.3016 (0.224 sec/step)
# INFO:tensorflow:global step 18980: loss = 2.3031 (0.216 sec/step)
# INFO:tensorflow:global step 18990: loss = 2.3022 (0.214 sec/step)
# INFO:tensorflow:global step 19000: loss = 2.3023 (0.221 sec/step)
# INFO:tensorflow:global step 19010: loss = 2.3027 (0.226 sec/step)
# INFO:tensorflow:global step 19020: loss = 2.3027 (0.230 sec/step)
# INFO:tensorflow:global step 19030: loss = 2.3030 (0.215 sec/step)
# INFO:tensorflow:global step 19040: loss = 2.3022 (0.213 sec/step)
# INFO:tensorflow:global step 19050: loss = 2.3021 (0.216 sec/step)
# INFO:tensorflow:global step 19060: loss = 2.3020 (0.219 sec/step)
# INFO:tensorflow:global step 19070: loss = 2.3024 (0.226 sec/step)
# INFO:tensorflow:global step 19080: loss = 2.3030 (0.215 sec/step)
# INFO:tensorflow:global step 19090: loss = 2.3026 (0.236 sec/step)
# INFO:tensorflow:global step 19100: loss = 2.3029 (0.218 sec/step)
# INFO:tensorflow:global step 19110: loss = 2.3022 (0.230 sec/step)
# INFO:tensorflow:global step 19120: loss = 2.3034 (0.220 sec/step)
# INFO:tensorflow:global step 19130: loss = 2.3028 (0.204 sec/step)
# INFO:tensorflow:global step 19140: loss = 2.3027 (0.224 sec/step)
# INFO:tensorflow:global step 19150: loss = 2.3033 (0.230 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Recording summary at step 19158.
# INFO:tensorflow:global step 19160: loss = 2.3032 (0.333 sec/step)
# INFO:tensorflow:global step 19170: loss = 2.3029 (0.218 sec/step)
# INFO:tensorflow:global step 19180: loss = 2.3026 (0.221 sec/step)
# INFO:tensorflow:global step 19190: loss = 2.3031 (0.216 sec/step)
# INFO:tensorflow:global step 19200: loss = 2.3026 (0.200 sec/step)
# INFO:tensorflow:global step 19210: loss = 2.3032 (0.239 sec/step)
# INFO:tensorflow:global step 19220: loss = 2.3017 (0.214 sec/step)
# INFO:tensorflow:global step 19230: loss = 2.3028 (0.243 sec/step)
# INFO:tensorflow:global step 19240: loss = 2.3026 (0.221 sec/step)
# INFO:tensorflow:global step 19250: loss = 2.3023 (0.216 sec/step)
# INFO:tensorflow:global step 19260: loss = 2.3017 (0.215 sec/step)
# INFO:tensorflow:global step 19270: loss = 2.3033 (0.215 sec/step)
# INFO:tensorflow:global step 19280: loss = 2.3024 (0.232 sec/step)
# INFO:tensorflow:global step 19290: loss = 2.3026 (0.211 sec/step)
# INFO:tensorflow:global step 19300: loss = 2.3026 (0.205 sec/step)
# INFO:tensorflow:global step 19310: loss = 2.3029 (0.223 sec/step)
# INFO:tensorflow:global step 19320: loss = 2.3026 (0.226 sec/step)
# INFO:tensorflow:global step 19330: loss = 2.3033 (0.206 sec/step)
# INFO:tensorflow:global step 19340: loss = 2.3019 (0.217 sec/step)
# INFO:tensorflow:global step 19350: loss = 2.3033 (0.234 sec/step)
# INFO:tensorflow:global step 19360: loss = 2.3027 (0.201 sec/step)
# INFO:tensorflow:global step 19370: loss = 2.3032 (0.229 sec/step)
# INFO:tensorflow:global step 19380: loss = 2.3020 (0.217 sec/step)
# INFO:tensorflow:global step 19390: loss = 2.3024 (0.224 sec/step)
# INFO:tensorflow:global step 19400: loss = 2.3034 (0.225 sec/step)
# INFO:tensorflow:global step 19410: loss = 2.3035 (0.224 sec/step)
# INFO:tensorflow:global step 19420: loss = 2.3027 (0.222 sec/step)
# INFO:tensorflow:global step 19430: loss = 2.3029 (0.216 sec/step)
# INFO:tensorflow:global step 19440: loss = 2.3024 (0.231 sec/step)
# INFO:tensorflow:global step 19450: loss = 2.3022 (0.223 sec/step)
# INFO:tensorflow:global step 19460: loss = 2.3024 (0.245 sec/step)
# INFO:tensorflow:global step 19470: loss = 2.3031 (0.215 sec/step)
# INFO:tensorflow:global step 19480: loss = 2.3028 (0.222 sec/step)
# INFO:tensorflow:global step 19490: loss = 2.3022 (0.203 sec/step)
# INFO:tensorflow:global step 19500: loss = 2.3023 (0.215 sec/step)
# INFO:tensorflow:global step 19510: loss = 2.3036 (0.221 sec/step)
# INFO:tensorflow:global step 19520: loss = 2.3032 (0.221 sec/step)
# INFO:tensorflow:global step 19530: loss = 2.3025 (0.235 sec/step)
# INFO:tensorflow:global step 19540: loss = 2.3036 (0.209 sec/step)
# INFO:tensorflow:global step 19550: loss = 2.3023 (0.237 sec/step)
# INFO:tensorflow:global step 19560: loss = 2.3028 (0.209 sec/step)
# INFO:tensorflow:global step 19570: loss = 2.3027 (0.222 sec/step)
# INFO:tensorflow:global step 19580: loss = 2.3027 (0.206 sec/step)
# INFO:tensorflow:global step 19590: loss = 2.3034 (0.235 sec/step)
# INFO:tensorflow:global step 19600: loss = 2.3027 (0.220 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/5deep/model.ckpt
# INFO:tensorflow:Recording summary at step 19607.
# INFO:tensorflow:global step 19610: loss = 2.3018 (0.288 sec/step)
# INFO:tensorflow:global step 19620: loss = 2.3029 (0.226 sec/step)
# INFO:tensorflow:global step 19630: loss = 2.3023 (0.223 sec/step)
# INFO:tensorflow:global step 19640: loss = 2.3024 (0.210 sec/step)
# INFO:tensorflow:global step 19650: loss = 2.3025 (0.209 sec/step)
# INFO:tensorflow:global step 19660: loss = 2.3022 (0.214 sec/step)
# INFO:tensorflow:global step 19670: loss = 2.3021 (0.235 sec/step)
# INFO:tensorflow:global step 19680: loss = 2.3034 (0.211 sec/step)
# INFO:tensorflow:global step 19690: loss = 2.3030 (0.227 sec/step)
# INFO:tensorflow:global step 19700: loss = 2.3028 (0.219 sec/step)
# INFO:tensorflow:global step 19710: loss = 2.3026 (0.215 sec/step)
# INFO:tensorflow:global step 19720: loss = 2.3030 (0.215 sec/step)
# INFO:tensorflow:global step 19730: loss = 2.3035 (0.232 sec/step)
# INFO:tensorflow:global step 19740: loss = 2.3031 (0.221 sec/step)
# INFO:tensorflow:global step 19750: loss = 2.3019 (0.243 sec/step)
# INFO:tensorflow:global step 19760: loss = 2.3023 (0.217 sec/step)
# INFO:tensorflow:global step 19770: loss = 2.3021 (0.216 sec/step)
# INFO:tensorflow:global step 19780: loss = 2.3027 (0.226 sec/step)
# INFO:tensorflow:global step 19790: loss = 2.3031 (0.219 sec/step)
# INFO:tensorflow:global step 19800: loss = 2.3034 (0.212 sec/step)
# INFO:tensorflow:global step 19810: loss = 2.3029 (0.212 sec/step)
# INFO:tensorflow:global step 19820: loss = 2.3024 (0.219 sec/step)
# INFO:tensorflow:global step 19830: loss = 2.3028 (0.220 sec/step)
# INFO:tensorflow:global step 19840: loss = 2.3023 (0.216 sec/step)
# INFO:tensorflow:global step 19850: loss = 2.3027 (0.223 sec/step)
# INFO:tensorflow:global step 19860: loss = 2.3030 (0.231 sec/step)
# INFO:tensorflow:global step 19870: loss = 2.3029 (0.234 sec/step)
# INFO:tensorflow:global step 19880: loss = 2.3029 (0.214 sec/step)
# INFO:tensorflow:global step 19890: loss = 2.3029 (0.204 sec/step)
# INFO:tensorflow:global step 19900: loss = 2.3029 (0.217 sec/step)
# INFO:tensorflow:global step 19910: loss = 2.3030 (0.227 sec/step)
# INFO:tensorflow:global step 19920: loss = 2.3019 (0.210 sec/step)
# INFO:tensorflow:global step 19930: loss = 2.3035 (0.225 sec/step)
# INFO:tensorflow:global step 19940: loss = 2.3029 (0.241 sec/step)
# INFO:tensorflow:global step 19950: loss = 2.3022 (0.245 sec/step)
# INFO:tensorflow:global step 19960: loss = 2.3031 (0.222 sec/step)
# INFO:tensorflow:global step 19970: loss = 2.3021 (0.209 sec/step)
# INFO:tensorflow:global step 19980: loss = 2.3025 (0.242 sec/step)
# INFO:tensorflow:global step 19990: loss = 2.3026 (0.205 sec/step)
# INFO:tensorflow:global step 20000: loss = 2.3017 (0.209 sec/step)
# INFO:tensorflow:Stopping Training.
# INFO:tensorflow:Finished training! Saving model to disk.
# Finished training. Final batch loss 2
# CPU times: user 2h 22min 12s, sys: 34min 9s, total: 2h 56min 21s
# Wall time: 1h 14min 51s

# %%
# %%time

# This might take a few minutes.
with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.DEBUG)
    
    dataset = cifar10.get_split('test', cifar10_data_dir)
    images, _, labels = load_batch(dataset)
    
    logits = cnn_relu(images, num_classes=dataset.num_classes, is_training=False)
    predictions = tf.argmax(logits, 1)
    
    # Define the metrics:
    names_to_values, names_to_updates = slim.metrics.aggregate_metric_map({
        'eval/mse':slim.metrics.streaming_mean_squared_error(predictions, labels),
        'eval/Accuracy': slim.metrics.streaming_accuracy(predictions, labels),
        'eval/TruePositives': slim.metrics.streaming_true_positives(predictions, labels),        
        'eval/TrueNegatives': slim.metrics.streaming_true_negatives(predictions, labels),
        'eval/FalsePositives': slim.metrics.streaming_false_positives(predictions, labels),
        'eval/FalseNegatives': slim.metrics.streaming_false_negatives(predictions, labels),
        'eval/Recall5': slim.metrics.streaming_sparse_recall_at_k(logits, labels, 5),
    })

    print('Running evaluation Loop...')
    checkpoint_path = tf.train.latest_checkpoint(train_dir)
    metric_values = slim.evaluation.evaluate_once(
        master='',
        checkpoint_path=checkpoint_path,
        logdir=train_dir,
        eval_op=list(names_to_updates.values()),
        final_op=list(names_to_values.values())
    )

    names_to_values = dict(zip(names_to_values.keys(), metric_values))
    for name in names_to_values:
        print('%s: %f' % (name, names_to_values[name]))
# Out:
# WARNING:tensorflow:From <timed exec>:15: streaming_accuracy (from tensorflow.contrib.metrics.python.ops.metric_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.metrics.accuracy. Note that the order of the inputs of labels and predictions have been switched.
# Running evaluation Loop...
# INFO:tensorflow:Starting evaluation at 2017-12-04-00:45:29
# INFO:tensorflow:Restoring parameters from /tmp/cifar10/5deep/model.ckpt-20000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-12-04-00:45:30
# eval/mse: 12.289062
# eval/Accuracy: 0.085938
# eval/FalseNegatives: 0.000000
# eval/Recall5: 0.546875
# eval/TrueNegatives: 0.000000
# eval/FalsePositives: 11.000000
# eval/TruePositives: 117.000000
# CPU times: user 1.82 s, sys: 396 ms, total: 2.21 s
# Wall time: 1.28 s

# %%
# %%time
batch_size = 10
with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.INFO)
    
    dataset = cifar10.get_split('test',cifar10_data_dir)
    images, images_raw, labels = load_batch(dataset, height=image_size, width=image_size)
    
    # Create the model, use the default arg scope to configure the batch norm parameters.
    logits = cnn_relu(images, num_classes=dataset.num_classes, is_training=True)
    probabilities = tf.nn.softmax(logits)
    
    checkpoint_path = tf.train.latest_checkpoint(train_dir)
    init_fn = slim.assign_from_checkpoint_fn(
      checkpoint_path,
      slim.get_variables_to_restore())
    
    with tf.Session() as sess:
        with slim.queues.QueueRunners(sess):
            sess.run(tf.local_variables_initializer())
            init_fn(sess)
            np_probabilities, np_images_raw, np_labels = sess.run([probabilities, images_raw, labels])
    
            for i in range(batch_size): 
                image = np_images_raw[i, :, :, :]
                true_label = np_labels[i]
                predicted_label = np.argmax(np_probabilities[i, :])
                predicted_name = dataset.labels_to_names[predicted_label]
                true_name = dataset.labels_to_names[true_label]
                
                plt.figure()
                plt.imshow(image.astype(np.uint8))
                plt.title('Ground Truth: [%s], Prediction [%s]' % (true_name, predicted_name))
                plt.axis('off')
                plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/cifar10/5deep/model.ckpt-20000
# CPU times: user 3.54 s, sys: 1.72 s, total: 5.27 s
# Wall time: 1.84 s
