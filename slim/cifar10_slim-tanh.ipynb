# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
# %pylab
# %matplotlib inline
import os
import math
import time
import tensorflow as tf
from datasets import dataset_utils,cifar10
from tensorflow.contrib import slim
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # lrn적용한 버젼!

# %%
dropout_keep_prob=0.8
image_size = 32
step=20000
learning_rate=0.0002
train_dir = '/tmp/cifar10/tanh'

# %%
cifar10_data_dir='/media/ramdisk/data/cifar10'

# %%
display_step=2

with tf.Graph().as_default(): 
    dataset = cifar10.get_split('train', cifar10_data_dir)
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
        dataset, common_queue_capacity=32, common_queue_min=1)
    image, label = data_provider.get(['image', 'label'])

    with tf.Session() as sess:    
        with slim.queues.QueueRunners(sess):
            for i in range(display_step):
                np_image, np_label = sess.run([image, label])
                height, width, _ = np_image.shape
                class_name = name = dataset.labels_to_names[np_label]
                
                plt.figure()
                plt.imshow(np_image)
                plt.title('%s, %d x %d' % (name, height, width))
                plt.axis('off')
                plt.show()

# %%
def cnn_tanh(images, num_classes, is_training):
    #https://github.com/agrawalnishant/tensorflow-1/tree/master/tensorflow/contrib/slim 
    ##vgg와  cifarndet을 참조함
    with slim.arg_scope([slim.max_pool2d], stride=2): 

        net = slim.repeat(images, 2, slim.conv2d, 64, [3, 3], scope='conv1',activation_fn=tf.tanh)
        net = slim.max_pool2d(net, [2, 2], scope='pool1')
        net = slim.repeat(net, 2, slim.conv2d, 128, [3, 3], scope='conv2',activation_fn=tf.tanh)
        net = slim.max_pool2d(net, [2, 2], scope='pool2')
        net = slim.repeat(net, 4, slim.conv2d, 256, [3, 3], scope='conv3',activation_fn=tf.tanh)
        net = slim.max_pool2d(net, [2, 2], scope='pool3')
        net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv4',activation_fn=tf.tanh)
        net = slim.max_pool2d(net, [2, 2], scope='pool4')
       
        net = slim.conv2d(net, 512, [2, 2], padding="VALID", scope='fc6')
        net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                         scope='dropout6')
        net = slim.conv2d(net, 512, [1, 1], scope='fc8', activation_fn=None)
        net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                           scope='dropout7')
        net = slim.conv2d(net, num_classes, [1, 1],
                          activation_fn=None,
                          normalizer_fn=None,
                          scope='fc9')
        
        net = tf.squeeze(net, [1,2],name='fc9/squeezed')
        
        return net

# %%
from preprocessing import cifarnet_preprocessing

def load_batch(dataset, batch_size=128, height=image_size, width=image_size, is_training=False):
    """Loads a single batch of data.
    
    Args:
      dataset: The dataset to load.
      batch_size: The number of images in the batch.
      height: The size of each image after preprocessing.
      width: The size of each image after preprocessing.
      is_training: Whether or not we're currently training or evaluating.
    
    Returns:
      images: A Tensor of size [batch_size, height, width, 3], image samples that have been preprocessed.
      images_raw: A Tensor of size [batch_size, height, width, 3], image samples that can be used for visualization.
      labels: A Tensor of size [batch_size], whose values range between 0 and dataset.num_classes.
    """
    
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
        dataset, common_queue_capacity=128,
        common_queue_min=32)
    image_raw, label = data_provider.get(['image', 'label'])
    
    # Preprocess image for usage by Inception.
    image = cifarnet_preprocessing.preprocess_image(image_raw, height, width, is_training=is_training)
    
    # Preprocess the image for display purposes.
    image_raw = tf.expand_dims(image_raw, 0)
    image_raw = tf.image.resize_images(image_raw, [height, width])
    image_raw = tf.squeeze(image_raw)

    # Batch it up.
    images, images_raw, labels = tf.train.batch(
          [image, image_raw, label],
          batch_size=batch_size,
          num_threads=4,
          capacity=4 * batch_size)
    
    return images, images_raw, labels

# %%
# %%time
# This might take a few minutes.

print('Will save model to %s' % train_dir)

with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.INFO)

    dataset = cifar10.get_split('train', cifar10_data_dir)
    images, _, labels = load_batch(dataset)
  
    # Create the model:
    logits =cnn_tanh(images, num_classes=dataset.num_classes, is_training=True)
 
    # Specify the loss function:
    one_hot_labels = slim.one_hot_encoding(labels, dataset.num_classes)
    slim.losses.softmax_cross_entropy(logits, one_hot_labels)
    total_loss = slim.losses.get_total_loss()
    
    # Create some summaries to visualize the training process:
    tf.summary.scalar('losses/Total Loss', total_loss)
    
    # Specify the optimizer and create the train op:
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    train_op = slim.learning.create_train_op(total_loss, optimizer)

    # Run the training:
    final_loss = slim.learning.train(
      train_op,
      logdir=train_dir,
      number_of_steps=step, 
          log_every_n_steps=10,
        save_interval_secs=100,
      save_summaries_secs=100)
  
    print('Finished training. Final batch loss %d' % final_loss)
# Out:
# Will save model to /tmp/cifar10/tanh
# WARNING:tensorflow:From <timed exec>:16: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:399: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:152: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# WARNING:tensorflow:From <timed exec>:17: get_total_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_total_loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:262: get_losses (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_losses instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:264: get_regularization_losses (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_regularization_losses instead.
# INFO:tensorflow:Summary name losses/Total Loss is illegal; using losses/Total_Loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/training/python/training/training.py:412: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# INFO:tensorflow:Starting Session.
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/tanh/model.ckpt
# INFO:tensorflow:Starting Queues.
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Recording summary at step 0.
# INFO:tensorflow:global step 10: loss = 2.0573 (0.111 sec/step)
# INFO:tensorflow:global step 20: loss = 1.9373 (0.102 sec/step)
# INFO:tensorflow:global step 30: loss = 2.0554 (0.108 sec/step)
# INFO:tensorflow:global step 40: loss = 1.7956 (0.103 sec/step)
# INFO:tensorflow:global step 50: loss = 1.6969 (0.103 sec/step)
# INFO:tensorflow:global step 60: loss = 1.6456 (0.104 sec/step)
# INFO:tensorflow:global step 70: loss = 1.7511 (0.104 sec/step)
# INFO:tensorflow:global step 80: loss = 1.6384 (0.105 sec/step)
# INFO:tensorflow:global step 90: loss = 1.5368 (0.119 sec/step)
# INFO:tensorflow:global step 100: loss = 1.4777 (0.105 sec/step)
# INFO:tensorflow:global step 110: loss = 1.4175 (0.116 sec/step)
# INFO:tensorflow:global step 120: loss = 1.5168 (0.108 sec/step)
sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/tanh/model.ckpt
# INFO:tensorflow:global_step/sec: 9.00985
# INFO:tensorflow:Recording summary at step 6289.
# INFO:tensorflow:global step 6290: loss = 0.1766 (0.321 sec/step)
# INFO:tensorflow:global step 6300: loss = 0.2816 (0.113 sec/step)
# INFO:tensorflow:global step 6310: loss = 0.1062 (0.104 sec/step)
# INFO:tensorflow:global step 6320: loss = 0.2240 (0.112 sec/step)
# INFO:tensorflow:global step 6330: loss = 0.2168 (0.103 sec/step)
# INFO:tensorflow:global step 6340: loss = 0.0979 (0.103 sec/step)
# INFO:tensorflow:global step 6350: loss = 0.0996 (0.106 sec/step)
# INFO:tensorflow:global step 6360: loss = 0.1574 (0.109 sec/step)
# INFO:tensorflow:global step 6370: loss = 0.1107 (0.105 sec/step)
# INFO:tensorflow:global step 6380: loss = 0.1175 (0.105 sec/step)
# INFO:tensorflow:global step 6390: loss = 0.1044 (0.126 sec/step)
# INFO:tensorflow:global step 6400: loss = 0.1030 (0.107 sec/step)
# INFO:tensorflow:global step 6410: loss = 0.0891 (0.116 sec/step)
# INFO:tensorflow:global step 6420: loss = 0.1456 (0.105 sec/step)
# INFO:tensorflow:global step 6430: loss = 0.0600 (0.108 sec/step)
# INFO:tensorflow:global step 6440: loss = 0.1410 (0.110 sec/step)
# INFO:tensorflow:global step 6450: loss = 0.1152 (0.105 sec/step)
# INFO:tensorflow:global step 6460: loss = 0.1736 (0.111 sec/step)
# INFO:tensorflow:global step 6470: loss = 0.0938 (0.108 sec/step)
# INFO:tensorflow:global step 6480: loss = 0.0718 (0.109 sec/step)
# INFO:tensorflow:global step 6490: loss = 0.1482 (0.106 sec/step)
# INFO:tensorflow:global step 6500: loss = 0.1038 (0.122 sec/step)
# INFO:tensorflow:global step 6510: loss = 0.0859 (0.100 sec/step)
# INFO:tensorflow:global step 6520: loss = 0.0476 (0.108 sec/step)
# INFO:tensorflow:global step 6530: loss = 0.0936 (0.101 sec/step)
# INFO:tensorflow:global step 6540: loss = 0.0759 (0.101 sec/step)
# INFO:tensorflow:global step 6550: loss = 0.0677 (0.100 sec/step)
# INFO:tensorflow:global step 6560: loss = 0.0758 (0.102 sec/step)
# INFO:tensorflow:global step 6570: loss = 0.0990 (0.116 sec/step)
# INFO:tensorflow:global step 6580: loss = 0.1415 (0.111 sec/step)
# INFO:tensorflow:global step 6590: loss = 0.2170 (0.146 sec/step)
# INFO:tensorflow:global step 6600: loss = 0.2215 (0.108 sec/step)
# INFO:tensorflow:global step 6610: loss = 0.0542 (0.110 sec/step)
# INFO:tensorflow:global step 6620: loss = 0.1044 (0.103 sec/step)
# INFO:tensorflow:global step 6630: loss = 0.1471 (0.101 sec/step)
# INFO:tensorflow:global step 6640: loss = 0.1958 (0.101 sec/step)
# INFO:tensorflow:global step 6650: loss = 0.0832 (0.118 sec/step)
# INFO:tensorflow:global step 6660: loss = 0.0611 (0.107 sec/step)
# INFO:tensorflow:global step 6670: loss = 0.1127 (0.121 sec/step)
# INFO:tensorflow:global step 6680: loss = 0.0527 (0.123 sec/step)
# INFO:tensorflow:global step 6690: loss = 0.1098 (0.123 sec/step)
# INFO:tensorflow:global step 6700: loss = 0.1123 (0.118 sec/step)
sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/tanh/model.ckpt
# INFO:tensorflow:Recording summary at step 17979.
# INFO:tensorflow:global step 17980: loss = 0.0113 (0.185 sec/step)
# INFO:tensorflow:global step 17990: loss = 0.0234 (0.113 sec/step)
# INFO:tensorflow:global step 18000: loss = 0.0244 (0.100 sec/step)
# INFO:tensorflow:global step 18010: loss = 0.0509 (0.115 sec/step)
# INFO:tensorflow:global step 18020: loss = 0.0205 (0.109 sec/step)
# INFO:tensorflow:global step 18030: loss = 0.0515 (0.135 sec/step)
# INFO:tensorflow:global step 18040: loss = 0.0126 (0.102 sec/step)
# INFO:tensorflow:global step 18050: loss = 0.0260 (0.107 sec/step)
# INFO:tensorflow:global step 18060: loss = 0.0965 (0.108 sec/step)
# INFO:tensorflow:global step 18070: loss = 0.1000 (0.115 sec/step)
# INFO:tensorflow:global step 18080: loss = 0.0461 (0.122 sec/step)
# INFO:tensorflow:global step 18090: loss = 0.0924 (0.108 sec/step)
# INFO:tensorflow:global step 18100: loss = 0.0667 (0.111 sec/step)
# INFO:tensorflow:global step 18110: loss = 0.0646 (0.110 sec/step)
# INFO:tensorflow:global step 18120: loss = 0.0226 (0.103 sec/step)
# INFO:tensorflow:global step 18130: loss = 0.0921 (0.104 sec/step)
# INFO:tensorflow:global step 18140: loss = 0.0062 (0.101 sec/step)
# INFO:tensorflow:global step 18150: loss = 0.1050 (0.124 sec/step)
# INFO:tensorflow:global step 18160: loss = 0.0422 (0.112 sec/step)
# INFO:tensorflow:global step 18170: loss = 0.1559 (0.115 sec/step)
# INFO:tensorflow:global step 18180: loss = 0.0329 (0.118 sec/step)
# INFO:tensorflow:global step 18190: loss = 0.0900 (0.108 sec/step)
# INFO:tensorflow:global step 18200: loss = 0.0224 (0.109 sec/step)
# INFO:tensorflow:global step 18210: loss = 0.1024 (0.110 sec/step)
# INFO:tensorflow:global step 18220: loss = 0.0783 (0.107 sec/step)
# INFO:tensorflow:global step 18230: loss = 0.0122 (0.106 sec/step)
# INFO:tensorflow:global step 18240: loss = 0.0620 (0.114 sec/step)
# INFO:tensorflow:global step 18250: loss = 0.0506 (0.105 sec/step)
# INFO:tensorflow:global step 18260: loss = 0.0704 (0.100 sec/step)
# INFO:tensorflow:global step 18270: loss = 0.0476 (0.116 sec/step)
# INFO:tensorflow:global step 18280: loss = 0.0239 (0.102 sec/step)
# INFO:tensorflow:global step 18290: loss = 0.0191 (0.103 sec/step)
# INFO:tensorflow:global step 18300: loss = 0.0196 (0.110 sec/step)
# INFO:tensorflow:global step 18310: loss = 0.0323 (0.122 sec/step)
# INFO:tensorflow:global step 18320: loss = 0.0862 (0.102 sec/step)
# INFO:tensorflow:global step 18330: loss = 0.0713 (0.102 sec/step)
# INFO:tensorflow:global step 18340: loss = 0.0397 (0.117 sec/step)
# INFO:tensorflow:global step 18350: loss = 0.0474 (0.115 sec/step)
# INFO:tensorflow:global step 18360: loss = 0.1201 (0.106 sec/step)
# INFO:tensorflow:global step 18370: loss = 0.0771 (0.124 sec/step)
# INFO:tensorflow:global step 18380: loss = 0.1410 (0.104 sec/step)
# INFO:tensorflow:global step 18390: loss = 0.0362 (0.111 sec/step)
# INFO:tensorflow:global step 18400: loss = 0.0188 (0.112 sec/step)
# INFO:tensorflow:global step 18410: loss = 0.0047 (0.106 sec/step)
# INFO:tensorflow:global step 18420: loss = 0.0392 (0.110 sec/step)
sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/tanh/model.ckpt
# INFO:tensorflow:Recording summary at step 18886.
# INFO:tensorflow:global step 18890: loss = 0.0241 (0.113 sec/step)
# INFO:tensorflow:global step 18900: loss = 0.0213 (0.117 sec/step)
# INFO:tensorflow:global step 18910: loss = 0.0755 (0.105 sec/step)
# INFO:tensorflow:global step 18920: loss = 0.0311 (0.103 sec/step)
# INFO:tensorflow:global step 18930: loss = 0.0801 (0.099 sec/step)
# INFO:tensorflow:global step 18940: loss = 0.0314 (0.111 sec/step)
# INFO:tensorflow:global step 18950: loss = 0.0457 (0.108 sec/step)
# INFO:tensorflow:global step 18960: loss = 0.0816 (0.117 sec/step)
# INFO:tensorflow:global step 18970: loss = 0.0182 (0.114 sec/step)
# INFO:tensorflow:global step 18980: loss = 0.0673 (0.112 sec/step)
# INFO:tensorflow:global step 18990: loss = 0.0910 (0.105 sec/step)
# INFO:tensorflow:global step 19000: loss = 0.0016 (0.110 sec/step)
# INFO:tensorflow:global step 19010: loss = 0.0618 (0.104 sec/step)
# INFO:tensorflow:global step 19020: loss = 0.0306 (0.111 sec/step)
# INFO:tensorflow:global step 19030: loss = 0.0452 (0.107 sec/step)
# INFO:tensorflow:global step 19040: loss = 0.0480 (0.111 sec/step)
# INFO:tensorflow:global step 19050: loss = 0.0213 (0.115 sec/step)
# INFO:tensorflow:global step 19060: loss = 0.0568 (0.115 sec/step)
# INFO:tensorflow:global step 19070: loss = 0.0621 (0.101 sec/step)
# INFO:tensorflow:global step 19080: loss = 0.0403 (0.109 sec/step)
# INFO:tensorflow:global step 19090: loss = 0.0252 (0.100 sec/step)
# INFO:tensorflow:global step 19100: loss = 0.0099 (0.116 sec/step)
# INFO:tensorflow:global step 19110: loss = 0.0858 (0.101 sec/step)
# INFO:tensorflow:global step 19120: loss = 0.0159 (0.105 sec/step)
# INFO:tensorflow:global step 19130: loss = 0.0338 (0.109 sec/step)
# INFO:tensorflow:global step 19140: loss = 0.0106 (0.109 sec/step)
# INFO:tensorflow:global step 19150: loss = 0.0588 (0.112 sec/step)
# INFO:tensorflow:global step 19160: loss = 0.0503 (0.113 sec/step)
# INFO:tensorflow:global step 19170: loss = 0.0129 (0.103 sec/step)
# INFO:tensorflow:global step 19180: loss = 0.1072 (0.102 sec/step)
# INFO:tensorflow:global step 19190: loss = 0.0102 (0.106 sec/step)
# INFO:tensorflow:global step 19200: loss = 0.0595 (0.106 sec/step)
# INFO:tensorflow:global step 19210: loss = 0.0048 (0.101 sec/step)
# INFO:tensorflow:global step 19220: loss = 0.0090 (0.101 sec/step)
# INFO:tensorflow:global step 19230: loss = 0.1100 (0.103 sec/step)
# INFO:tensorflow:global step 19240: loss = 0.0354 (0.111 sec/step)
# INFO:tensorflow:global step 19670: loss = 0.0446 (0.103 sec/step)
# INFO:tensorflow:global step 19680: loss = 0.0107 (0.109 sec/step)
# INFO:tensorflow:global step 19690: loss = 0.0165 (0.119 sec/step)
# INFO:tensorflow:global step 19700: loss = 0.1086 (0.112 sec/step)
# INFO:tensorflow:global step 19710: loss = 0.0897 (0.113 sec/step)
# INFO:tensorflow:global step 19720: loss = 0.1028 (0.115 sec/step)
# INFO:tensorflow:global step 19730: loss = 0.0453 (0.111 sec/step)
# INFO:tensorflow:global step 19740: loss = 0.0502 (0.105 sec/step)
# INFO:tensorflow:global step 19750: loss = 0.0117 (0.106 sec/step)
# INFO:tensorflow:global step 19760: loss = 0.0140 (0.103 sec/step)
# INFO:tensorflow:global step 19770: loss = 0.0932 (0.107 sec/step)
# INFO:tensorflow:global step 19780: loss = 0.0950 (0.105 sec/step)
# INFO:tensorflow:global step 19790: loss = 0.0497 (0.101 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/tanh/model.ckpt
# INFO:tensorflow:Recording summary at step 19791.
# INFO:tensorflow:global step 19800: loss = 0.0214 (0.101 sec/step)
# INFO:tensorflow:global step 19810: loss = 0.0977 (0.104 sec/step)
# INFO:tensorflow:global step 19820: loss = 0.0197 (0.106 sec/step)
# INFO:tensorflow:global step 19830: loss = 0.0558 (0.124 sec/step)
# INFO:tensorflow:global step 19840: loss = 0.0109 (0.099 sec/step)
# INFO:tensorflow:global step 19850: loss = 0.0398 (0.116 sec/step)
# INFO:tensorflow:global step 19860: loss = 0.0144 (0.105 sec/step)
# INFO:tensorflow:global step 19870: loss = 0.0561 (0.118 sec/step)
# INFO:tensorflow:global step 19880: loss = 0.0452 (0.119 sec/step)
# INFO:tensorflow:global step 19890: loss = 0.0851 (0.106 sec/step)
# INFO:tensorflow:global step 19900: loss = 0.0165 (0.110 sec/step)
# INFO:tensorflow:global step 19910: loss = 0.0579 (0.105 sec/step)
# INFO:tensorflow:global step 19920: loss = 0.0837 (0.111 sec/step)
# INFO:tensorflow:global step 19930: loss = 0.1444 (0.120 sec/step)
# INFO:tensorflow:global step 19940: loss = 0.0382 (0.103 sec/step)
# INFO:tensorflow:global step 19950: loss = 0.0313 (0.117 sec/step)
# INFO:tensorflow:global step 19960: loss = 0.0690 (0.110 sec/step)
# INFO:tensorflow:global step 19970: loss = 0.0812 (0.101 sec/step)
# INFO:tensorflow:global step 19980: loss = 0.0477 (0.108 sec/step)
# INFO:tensorflow:global step 19990: loss = 0.0794 (0.110 sec/step)
# INFO:tensorflow:global step 20000: loss = 0.0125 (0.100 sec/step)
# INFO:tensorflow:Stopping Training.
# INFO:tensorflow:Finished training! Saving model to disk.
# Finished training. Final batch loss 0
# CPU times: user 1h 58min 38s, sys: 25min 29s, total: 2h 24min 7s
# Wall time: 37min 5s

# %%
# %%time

# This might take a few minutes.
with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.DEBUG)
    
    dataset = cifar10.get_split('test', cifar10_data_dir)
    images, _, labels = load_batch(dataset)
    
    logits = cnn_tanh(images, num_classes=dataset.num_classes, is_training=False)
    predictions = tf.argmax(logits, 1)
    
    # Define the metrics:
    names_to_values, names_to_updates = slim.metrics.aggregate_metric_map({
        'eval/mse':slim.metrics.streaming_mean_squared_error(predictions, labels),
        'eval/Accuracy': slim.metrics.streaming_accuracy(predictions, labels),
        'eval/TruePositives': slim.metrics.streaming_true_positives(predictions, labels),        
        'eval/TrueNegatives': slim.metrics.streaming_true_negatives(predictions, labels),
        'eval/FalsePositives': slim.metrics.streaming_false_positives(predictions, labels),
        'eval/FalseNegatives': slim.metrics.streaming_false_negatives(predictions, labels),
        'eval/Recall5': slim.metrics.streaming_sparse_recall_at_k(logits, labels, 5),
    })

    print('Running evaluation Loop...')
    checkpoint_path = tf.train.latest_checkpoint(train_dir)
    metric_values = slim.evaluation.evaluate_once(
        master='',
        checkpoint_path=checkpoint_path,
        logdir=train_dir,
        eval_op=list(names_to_updates.values()),
        final_op=list(names_to_values.values())
    )

    names_to_values = dict(zip(names_to_values.keys(), metric_values))
    for name in names_to_values:
        print('%s: %f' % (name, names_to_values[name]))
# Out:
# WARNING:tensorflow:From <timed exec>:15: streaming_accuracy (from tensorflow.contrib.metrics.python.ops.metric_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.metrics.accuracy. Note that the order of the inputs of labels and predictions have been switched.
# Running evaluation Loop...
# INFO:tensorflow:Starting evaluation at 2017-12-03-12:41:12
# INFO:tensorflow:Restoring parameters from /tmp/cifar10/tanh/model.ckpt-20000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-12-03-12:41:13
# eval/mse: 3.335938
# eval/FalseNegatives: 1.000000
# eval/Recall5: 0.984375
# eval/TruePositives: 115.000000
# eval/TrueNegatives: 9.000000
# eval/Accuracy: 0.773438
# eval/FalsePositives: 3.000000
# CPU times: user 1.8 s, sys: 344 ms, total: 2.14 s
# Wall time: 1.23 s

# %%
# %%time
batch_size = 10
with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.INFO)
    
    dataset = cifar10.get_split('test',cifar10_data_dir)
    images, images_raw, labels = load_batch(dataset, height=image_size, width=image_size)
    
    # Create the model, use the default arg scope to configure the batch norm parameters.
    logits = cnn_tanh(images, num_classes=dataset.num_classes, is_training=True)
    probabilities = tf.nn.softmax(logits)
    
    checkpoint_path = tf.train.latest_checkpoint(train_dir)
    init_fn = slim.assign_from_checkpoint_fn(
      checkpoint_path,
      slim.get_variables_to_restore())
    
    with tf.Session() as sess:
        with slim.queues.QueueRunners(sess):
            sess.run(tf.local_variables_initializer())
            init_fn(sess)
            np_probabilities, np_images_raw, np_labels = sess.run([probabilities, images_raw, labels])
    
            for i in range(batch_size): 
                image = np_images_raw[i, :, :, :]
                true_label = np_labels[i]
                predicted_label = np.argmax(np_probabilities[i, :])
                predicted_name = dataset.labels_to_names[predicted_label]
                true_name = dataset.labels_to_names[true_label]
                
                plt.figure()
                plt.imshow(image.astype(np.uint8))
                plt.title('Ground Truth: [%s], Prediction [%s]' % (true_name, predicted_name))
                plt.axis('off')
                plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/cifar10/tanh/model.ckpt-20000
# CPU times: user 3.41 s, sys: 1.74 s, total: 5.15 s
# Wall time: 1.74 s
