# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
# %pylab
# %matplotlib inline
import os
import math
import time
import tensorflow as tf
from datasets import dataset_utils,cifar10
from tensorflow.contrib import slim
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
dropout_keep_prob=0.8
image_size = 32
step=20000
learning_rate=0.0002
train_dir = '/tmp/cifar10/relu1'

# %%
cifar10_data_dir='/media/ramdisk/data/cifar10'

# %%
display_step=2

with tf.Graph().as_default(): 
    dataset = cifar10.get_split('train', cifar10_data_dir)
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
        dataset, common_queue_capacity=32, common_queue_min=1)
    image, label = data_provider.get(['image', 'label'])

    with tf.Session() as sess:    
        with slim.queues.QueueRunners(sess):
            for i in range(display_step):
                np_image, np_label = sess.run([image, label])
                height, width, _ = np_image.shape
                class_name = name = dataset.labels_to_names[np_label]
                
                plt.figure()
                plt.imshow(np_image)
                plt.title('%s, %d x %d' % (name, height, width))
                plt.axis('off')
                plt.show()

# %%
def cnn_relu(images, num_classes, is_training):
    #https://github.com/agrawalnishant/tensorflow-1/tree/master/tensorflow/contrib/slim 
    ##vgg와  cifarndet을 참조함
    with slim.arg_scope([slim.max_pool2d], stride=2): 

        net = slim.repeat(images, 2, slim.conv2d, 64, [3, 3], scope='conv1',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool1')
        net = slim.repeat(net, 2, slim.conv2d, 128, [3, 3], scope='conv2',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool2')
        net = slim.repeat(net, 4, slim.conv2d, 256, [3, 3], scope='conv3',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool3')
        net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv4',activation_fn=tf.nn.relu)
        net = slim.max_pool2d(net, [2, 2], scope='pool4')
       
        net = slim.conv2d(net, 512, [2, 2], padding="VALID", scope='fc6')
        net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                         scope='dropout6')
        net = slim.conv2d(net, 512, [1, 1], scope='fc8', activation_fn=None)
        net = slim.dropout(net, dropout_keep_prob, is_training=is_training,
                           scope='dropout7')
        net = slim.conv2d(net, num_classes, [1, 1],
                          activation_fn=None,
                          normalizer_fn=None,
                          scope='fc9')
        
        net = tf.squeeze(net, [1,2],name='fc9/squeezed')
        
        return net

# %%
from preprocessing import cifarnet_preprocessing

def load_batch(dataset, batch_size=128, height=image_size, width=image_size, is_training=False):
    """Loads a single batch of data.
    
    Args:
      dataset: The dataset to load.
      batch_size: The number of images in the batch.
      height: The size of each image after preprocessing.
      width: The size of each image after preprocessing.
      is_training: Whether or not we're currently training or evaluating.
    
    Returns:
      images: A Tensor of size [batch_size, height, width, 3], image samples that have been preprocessed.
      images_raw: A Tensor of size [batch_size, height, width, 3], image samples that can be used for visualization.
      labels: A Tensor of size [batch_size], whose values range between 0 and dataset.num_classes.
    """
    
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
        dataset, common_queue_capacity=128,
        common_queue_min=32)
    image_raw, label = data_provider.get(['image', 'label'])
    
    # Preprocess image for usage by Inception.
    image = cifarnet_preprocessing.preprocess_image(image_raw, height, width, is_training=is_training)
    
    # Preprocess the image for display purposes.
    image_raw = tf.expand_dims(image_raw, 0)
    image_raw = tf.image.resize_images(image_raw, [height, width])
    image_raw = tf.squeeze(image_raw)

    # Batch it up.
    images, images_raw, labels = tf.train.batch(
          [image, image_raw, label],
          batch_size=batch_size,
          num_threads=4,
          capacity=4 * batch_size)
    
    return images, images_raw, labels

# %%
# %%time
# This might take a few minutes.

print('Will save model to %s' % train_dir)

with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.INFO)

    dataset = cifar10.get_split('train', cifar10_data_dir)
    images, _, labels = load_batch(dataset)
  
    # Create the model:
    logits =cnn_relu(images, num_classes=dataset.num_classes, is_training=True)
 
    # Specify the loss function:
    one_hot_labels = slim.one_hot_encoding(labels, dataset.num_classes)
    slim.losses.softmax_cross_entropy(logits, one_hot_labels)
    total_loss = slim.losses.get_total_loss()
    
    # Create some summaries to visualize the training process:
    tf.summary.scalar('losses/Total Loss', total_loss)
    
    # Specify the optimizer and create the train op:
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    train_op = slim.learning.create_train_op(total_loss, optimizer)

    # Run the training:
    final_loss = slim.learning.train(
      train_op,
      logdir=train_dir,
      number_of_steps=step, 
          log_every_n_steps=10,
        save_interval_secs=100,
      save_summaries_secs=100)
  
    print('Finished training. Final batch loss %d' % final_loss)
# Out:
# Will save model to /tmp/cifar10/lelu1
# WARNING:tensorflow:From <timed exec>:16: softmax_cross_entropy (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.softmax_cross_entropy instead. Note that the order of the logits and labels arguments has been changed.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:398: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:399: compute_weighted_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.compute_weighted_loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:152: add_arg_scope.<locals>.func_with_args (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.add_loss instead.
# WARNING:tensorflow:From <timed exec>:17: get_total_loss (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_total_loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:262: get_losses (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_losses instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/losses/python/losses/loss_ops.py:264: get_regularization_losses (from tensorflow.contrib.losses.python.losses.loss_ops) is deprecated and will be removed after 2016-12-30.
# Instructions for updating:
# Use tf.losses.get_regularization_losses instead.
# INFO:tensorflow:Summary name losses/Total Loss is illegal; using losses/Total_Loss instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/training/python/training/training.py:412: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step
# INFO:tensorflow:Starting Session.
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/lelu1/model.ckpt
# INFO:tensorflow:Starting Queues.
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Recording summary at step 0.
# INFO:tensorflow:global step 10: loss = 2.2627 (0.099 sec/step)
# INFO:tensorflow:global step 20: loss = 2.1584 (0.097 sec/step)
# INFO:tensorflow:global step 30: loss = 2.1327 (0.118 sec/step)
# INFO:tensorflow:global step 40: loss = 2.1831 (0.109 sec/step)
# INFO:tensorflow:global step 50: loss = 2.0581 (0.097 sec/step)
# INFO:tensorflow:global step 60: loss = 2.0048 (0.100 sec/step)
# INFO:tensorflow:global step 70: loss = 2.0541 (0.121 sec/step)
# INFO:tensorflow:global step 80: loss = 1.8956 (0.103 sec/step)
# INFO:tensorflow:global step 90: loss = 1.8232 (0.107 sec/step)
# INFO:tensorflow:global step 100: loss = 1.9212 (0.099 sec/step)
# INFO:tensorflow:global step 110: loss = 1.8588 (0.105 sec/step)
# INFO:tensorflow:global step 120: loss = 1.7784 (0.102 sec/step)
# INFO:tensorflow:global step 3840: loss = 0.1920 (0.101 sec/step)
# INFO:tensorflow:global step 3850: loss = 0.2385 (0.101 sec/step)
# INFO:tensorflow:global step 3860: loss = 0.2229 (0.099 sec/step)
# INFO:tensorflow:global step 3870: loss = 0.3070 (0.102 sec/step)
# INFO:tensorflow:global step 3880: loss = 0.3490 (0.118 sec/step)
# INFO:tensorflow:global step 3890: loss = 0.2627 (0.100 sec/step)
# INFO:tensorflow:global step 3900: loss = 0.2698 (0.112 sec/step)
# INFO:tensorflow:global step 3910: loss = 0.2113 (0.109 sec/step)
# INFO:tensorflow:global step 3920: loss = 0.1768 (0.100 sec/step)
# INFO:tensorflow:global step 3930: loss = 0.2203 (0.105 sec/step)
# INFO:tensorflow:global step 3940: loss = 0.2009 (0.102 sec/step)
# INFO:tensorflow:global step 3950: loss = 0.2124 (0.098 sec/step)
# INFO:tensorflow:global step 3960: loss = 0.1286 (0.116 sec/step)
# INFO:tensorflow:global step 3970: loss = 0.2066 (0.114 sec/step)
# INFO:tensorflow:global step 3980: loss = 0.3184 (0.105 sec/step)
# INFO:tensorflow:global step 3990: loss = 0.1922 (0.114 sec/step)
# INFO:tensorflow:global step 4000: loss = 0.3078 (0.108 sec/step)
# INFO:tensorflow:global step 4010: loss = 0.3251 (0.119 sec/step)
# INFO:tensorflow:global step 4020: loss = 0.2372 (0.107 sec/step)
# INFO:tensorflow:global step 4030: loss = 0.2584 (0.098 sec/step)
# INFO:tensorflow:global step 4040: loss = 0.2481 (0.106 sec/step)
# INFO:tensorflow:global step 4050: loss = 0.1684 (0.110 sec/step)
# INFO:tensorflow:global step 4060: loss = 0.1910 (0.106 sec/step)
# INFO:tensorflow:global step 4070: loss = 0.2987 (0.104 sec/step)
# INFO:tensorflow:global step 4080: loss = 0.2321 (0.100 sec/step)
# INFO:tensorflow:global step 4090: loss = 0.2590 (0.115 sec/step)
# INFO:tensorflow:global step 4100: loss = 0.3612 (0.100 sec/step)
# INFO:tensorflow:global step 4110: loss = 0.2044 (0.102 sec/step)
# INFO:tensorflow:global step 4120: loss = 0.2045 (0.101 sec/step)
# INFO:tensorflow:global step 4130: loss = 0.2512 (0.104 sec/step)
# INFO:tensorflow:global step 4140: loss = 0.2524 (0.107 sec/step)
# INFO:tensorflow:global step 4150: loss = 0.1222 (0.109 sec/step)
# INFO:tensorflow:global step 4160: loss = 0.1529 (0.104 sec/step)
# INFO:tensorflow:global step 4170: loss = 0.1499 (0.116 sec/step)
# INFO:tensorflow:global step 4180: loss = 0.1548 (0.112 sec/step)
# INFO:tensorflow:global step 4190: loss = 0.3182 (0.109 sec/step)
# INFO:tensorflow:global step 4200: loss = 0.1672 (0.102 sec/step)
# INFO:tensorflow:global step 4210: loss = 0.1902 (0.100 sec/step)
# INFO:tensorflow:global step 4220: loss = 0.2319 (0.114 sec/step)
# INFO:tensorflow:global step 4230: loss = 0.2767 (0.101 sec/step)
# INFO:tensorflow:global step 4240: loss = 0.1900 (0.117 sec/step)
# INFO:tensorflow:global step 4250: loss = 0.1439 (0.103 sec/step)
# INFO:tensorflow:global step 4260: loss = 0.3786 (0.109 sec/step)
# INFO:tensorflow:global step 4270: loss = 0.1468 (0.106 sec/step)
# INFO:tensorflow:global step 4280: loss = 0.2040 (0.102 sec/step)
# INFO:tensorflow:global step 4290: loss = 0.2976 (0.105 sec/step)
# INFO:tensorflow:global step 4300: loss = 0.1410 (0.103 sec/step)
# INFO:tensorflow:global step 4310: loss = 0.1519 (0.104 sec/step)
# INFO:tensorflow:global step 4320: loss = 0.2680 (0.101 sec/step)
# INFO:tensorflow:global step 4330: loss = 0.1859 (0.101 sec/step)
# INFO:tensorflow:global step 4340: loss = 0.1808 (0.106 sec/step)
# INFO:tensorflow:global step 4350: loss = 0.1766 (0.104 sec/step)
# INFO:tensorflow:global step 4360: loss = 0.2798 (0.100 sec/step)
# INFO:tensorflow:global step 4370: loss = 0.2578 (0.101 sec/step)
# INFO:tensorflow:global step 4380: loss = 0.1658 (0.101 sec/step)
# INFO:tensorflow:global step 4390: loss = 0.1348 (0.099 sec/step)
# INFO:tensorflow:global step 4400: loss = 0.2179 (0.108 sec/step)
# INFO:tensorflow:global step 4410: loss = 0.2194 (0.117 sec/step)
# INFO:tensorflow:global step 4420: loss = 0.2339 (0.107 sec/step)
# INFO:tensorflow:global step 4430: loss = 0.2138 (0.103 sec/step)
# INFO:tensorflow:global step 4440: loss = 0.2411 (0.102 sec/step)
# INFO:tensorflow:global step 4450: loss = 0.3263 (0.107 sec/step)
# INFO:tensorflow:global step 4460: loss = 0.1453 (0.102 sec/step)
# INFO:tensorflow:global step 4470: loss = 0.1677 (0.111 sec/step)
# INFO:tensorflow:global step 4480: loss = 0.0635 (0.109 sec/step)
# INFO:tensorflow:global step 4490: loss = 0.0721 (0.106 sec/step)
# INFO:tensorflow:global step 4500: loss = 0.1040 (0.104 sec/step)
# INFO:tensorflow:global step 4510: loss = 0.2195 (0.111 sec/step)
# INFO:tensorflow:global step 4520: loss = 0.1527 (0.124 sec/step)
# INFO:tensorflow:global step 4530: loss = 0.1593 (0.098 sec/step)
# INFO:tensorflow:global step 4540: loss = 0.2530 (0.110 sec/step)
# INFO:tensorflow:global step 4550: loss = 0.1440 (0.113 sec/step)
# INFO:tensorflow:global step 4560: loss = 0.1245 (0.106 sec/step)
# INFO:tensorflow:global step 4570: loss = 0.1216 (0.102 sec/step)
# INFO:tensorflow:global step 4580: loss = 0.2366 (0.100 sec/step)
# INFO:tensorflow:global step 4590: loss = 0.1098 (0.108 sec/step)
# INFO:tensorflow:global step 4600: loss = 0.1471 (0.100 sec/step)
# INFO:tensorflow:global step 4610: loss = 0.1397 (0.100 sec/step)
# INFO:tensorflow:global step 4620: loss = 0.3201 (0.102 sec/step)
# INFO:tensorflow:global step 4630: loss = 0.1749 (0.102 sec/step)
# INFO:tensorflow:global step 4640: loss = 0.1729 (0.102 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10
# INFO:tensorflow:global step 5900: loss = 0.0826 (0.118 sec/step)
# INFO:tensorflow:global step 5910: loss = 0.0722 (0.103 sec/step)
# INFO:tensorflow:global step 5920: loss = 0.1359 (0.100 sec/step)
# INFO:tensorflow:global step 5930: loss = 0.1187 (0.110 sec/step)
# INFO:tensorflow:global step 5940: loss = 0.1257 (0.111 sec/step)
# INFO:tensorflow:global step 5950: loss = 0.0897 (0.100 sec/step)
# INFO:tensorflow:global step 5960: loss = 0.1543 (0.112 sec/step)
# INFO:tensorflow:global step 5970: loss = 0.0856 (0.101 sec/step)
# INFO:tensorflow:global step 5980: loss = 0.0663 (0.108 sec/step)
# INFO:tensorflow:global step 5990: loss = 0.0599 (0.105 sec/step)
# INFO:tensorflow:global step 6000: loss = 0.0351 (0.099 sec/step)
# INFO:tensorflow:global step 6010: loss = 0.0871 (0.112 sec/step)
# INFO:tensorflow:global step 6020: loss = 0.0791 (0.100 sec/step)
# INFO:tensorflow:global step 6030: loss = 0.0176 (0.100 sec/step)
# INFO:tensorflow:global step 6040: loss = 0.0523 (0.113 sec/step)
# INFO:tensorflow:global step 6050: loss = 0.0636 (0.111 sec/step)
# INFO:tensorflow:global step 6060: loss = 0.0892 (0.110 sec/step)
# INFO:tensorflow:global step 6070: loss = 0.0313 (0.116 sec/step)
# INFO:tensorflow:global step 6080: loss = 0.0820 (0.099 sec/step)
# INFO:tensorflow:global step 6090: loss = 0.0913 (0.100 sec/step)
# INFO:tensorflow:global step 6100: loss = 0.1064 (0.109 sec/step)
# INFO:tensorflow:global step 6110: loss = 0.0967 (0.110 sec/step)
# INFO:tensorflow:global step 6120: loss = 0.0782 (0.108 sec/step)
# INFO:tensorflow:global step 6130: loss = 0.0871 (0.108 sec/step)
# INFO:tensorflow:global step 6140: loss = 0.1104 (0.122 sec/step)
# INFO:tensorflow:global step 6150: loss = 0.1122 (0.115 sec/step)
# INFO:tensorflow:global step 6160: loss = 0.1222 (0.102 sec/step)
# INFO:tensorflow:global step 6170: loss = 0.0434 (0.115 sec/step)
# INFO:tensorflow:global step 6180: loss = 0.1741 (0.106 sec/step)
# INFO:tensorflow:global step 6190: loss = 0.1169 (0.118 sec/step)
# INFO:tensorflow:global step 6200: loss = 0.0193 (0.101 sec/step)
# INFO:tensorflow:global step 6210: loss = 0.0645 (0.099 sec/step)
# INFO:tensorflow:global step 6220: loss = 0.0357 (0.106 sec/step)
# INFO:tensorflow:global step 6230: loss = 0.0354 (0.109 sec/step)
# INFO:tensorflow:global step 6240: loss = 0.1412 (0.105 sec/step)
# INFO:tensorflow:global step 6250: loss = 0.1160 (0.108 sec/step)
# INFO:tensorflow:global step 6260: loss = 0.2203 (0.125 sec/step)
# INFO:tensorflow:global step 6270: loss = 0.0711 (0.104 sec/step)
# INFO:tensorflow:global step 6280: loss = 0.0391 (0.107 sec/step)
# INFO:tensorflow:global step 6290: loss = 0.1353 (0.115 sec/step)
# INFO:tensorflow:global step 6300: loss = 0.0951 (0.105 sec/step)
# INFO:tensorflow:global step 6310: loss = 0.0159 (0.108 sec/step)
# INFO:tensorflow:global step 6320: loss = 0.0552 (0.100 sec/step)
# INFO:tensorflow:global step 6330: loss = 0.2270 (0.116 sec/step)
# INFO:tensorflow:global step 6340: loss = 0.1344 (0.103 sec/step)
# INFO:tensorflow:global step 6350: loss = 0.1129 (0.104 sec/step)
# INFO:tensorflow:global step 6360: loss = 0.0323 (0.101 sec/step)
# INFO:tensorflow:global step 6370: loss = 0.1164 (0.104 sec/step)
# INFO:tensorflow:global step 6380: loss = 0.0671 (0.111 sec/step)
# INFO:tensorflow:global step 6390: loss = 0.0373 (0.102 sec/step)
# INFO:tensorflow:global step 6400: loss = 0.1028 (0.104 sec/step)
# INFO:tensorflow:global step 6410: loss = 0.0319 (0.115 sec/step)
# INFO:tensorflow:global step 6420: loss = 0.1009 (0.110 sec/step)
# INFO:tensorflow:global step 6430: loss = 0.0524 (0.106 sec/step)
# INFO:tensorflow:global step 6440: loss = 0.1446 (0.108 sec/step)
# INFO:tensorflow:global step 6450: loss = 0.1108 (0.100 sec/step)
# INFO:tensorflow:global step 6460: loss = 0.0888 (0.097 sec/step)
# INFO:tensorflow:global step 6470: loss = 0.0752 (0.102 sec/step)
# INFO:tensorflow:global step 6480: loss = 0.1429 (0.100 sec/step)
# INFO:tensorflow:global step 6490: loss = 0.1177 (0.099 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/lelu1/model.ckpt
# INFO:tensorflow:global_step/sec: 9.24001
# INFO:tensorflow:Recording summary at step 6495.
# INFO:tensorflow:global step 6500: loss = 0.0475 (0.102 sec/step)
# INFO:tensorflow:global step 6510: loss = 0.0906 (0.103 sec/step)
# INFO:tensorflow:global step 6520: loss = 0.0836 (0.104 sec/step)
# INFO:tensorflow:global step 6530: loss = 0.1079 (0.104 sec/step)
# INFO:tensorflow:global step 6540: loss = 0.0684 (0.104 sec/step)
# INFO:tensorflow:global step 6550: loss = 0.0974 (0.106 sec/step)
# INFO:tensorflow:global step 6560: loss = 0.0434 (0.104 sec/step)
# INFO:tensorflow:global step 6570: loss = 0.1668 (0.113 sec/step)
# INFO:tensorflow:global step 6580: loss = 0.0923 (0.104 sec/step)
# INFO:tensorflow:global step 6590: loss = 0.0454 (0.099 sec/step)
# INFO:tensorflow:global step 6600: loss = 0.0178 (0.105 sec/step)
# INFO:tensorflow:global step 6610: loss = 0.0886 (0.102 sec/step)
# INFO:tensorflow:global step 6620: loss = 0.0750 (0.103 sec/step)
# INFO:tensorflow:global step 6630: loss = 0.1227 (0.111 sec/step)
# INFO:tensorflow:global step 6640: loss = 0.0831 (0.100 sec/step)
# INFO:tensorflow:global step 6650: loss = 0.0596 (0.126 sec/step)
# INFO:tensorflow:global step 6660: loss = 0.0423 (0.101 sec/step)
# INFO:tensorflow:global step 6670: loss = 0.0527 (0.113 sec/step)
# INFO:tensorflow:global step 6680: loss = 0.0640 (0.100 sec/step)
# INFO:tensorflow:global step 6690: loss = 0.0255 (0.108 sec/step)
# INFO:tensorflow:global step 6700: loss = 0.0240 (0.101 sec/step)
# INFO:tensorflow:global step 18010: loss = 0.0051 (0.104 sec/step)
# INFO:tensorflow:global step 18020: loss = 0.0037 (0.110 sec/step)
# INFO:tensorflow:global step 18030: loss = 0.0182 (0.103 sec/step)
# INFO:tensorflow:global step 18040: loss = 0.0143 (0.109 sec/step)
# INFO:tensorflow:global step 18050: loss = 0.0181 (0.113 sec/step)
# INFO:tensorflow:global step 18060: loss = 0.0541 (0.109 sec/step)
# INFO:tensorflow:global step 18070: loss = 0.0771 (0.108 sec/step)
# INFO:tensorflow:global step 18080: loss = 0.0046 (0.110 sec/step)
# INFO:tensorflow:global step 18090: loss = 0.0235 (0.102 sec/step)
# INFO:tensorflow:global step 18100: loss = 0.0658 (0.110 sec/step)
# INFO:tensorflow:global step 18110: loss = 0.0064 (0.099 sec/step)
# INFO:tensorflow:global step 18120: loss = 0.0157 (0.110 sec/step)
# INFO:tensorflow:global step 18130: loss = 0.0324 (0.108 sec/step)
# INFO:tensorflow:global step 18140: loss = 0.0452 (0.102 sec/step)
# INFO:tensorflow:global step 18150: loss = 0.0250 (0.104 sec/step)
# INFO:tensorflow:global step 18160: loss = 0.0465 (0.107 sec/step)
# INFO:tensorflow:global step 18170: loss = 0.1063 (0.111 sec/step)
# INFO:tensorflow:global step 18180: loss = 0.0204 (0.110 sec/step)
# INFO:tensorflow:global step 18190: loss = 0.0105 (0.101 sec/step)
# INFO:tensorflow:global step 18200: loss = 0.0037 (0.103 sec/step)
# INFO:tensorflow:global step 18210: loss = 0.0284 (0.100 sec/step)
# INFO:tensorflow:global step 18220: loss = 0.0213 (0.106 sec/step)
# INFO:tensorflow:global step 18230: loss = 0.0763 (0.116 sec/step)
# INFO:tensorflow:global step 18240: loss = 0.0170 (0.104 sec/step)
# INFO:tensorflow:global step 18250: loss = 0.0172 (0.102 sec/step)
# INFO:tensorflow:global step 18260: loss = 0.0478 (0.108 sec/step)
# INFO:tensorflow:global step 18270: loss = 0.0176 (0.104 sec/step)
# INFO:tensorflow:global step 18280: loss = 0.0027 (0.115 sec/step)
# INFO:tensorflow:global step 18290: loss = 0.0078 (0.104 sec/step)
# INFO:tensorflow:global step 18300: loss = 0.0236 (0.124 sec/step)
# INFO:tensorflow:global step 18310: loss = 0.0269 (0.102 sec/step)
# INFO:tensorflow:global step 18320: loss = 0.0044 (0.104 sec/step)
# INFO:tensorflow:global step 18330: loss = 0.0119 (0.115 sec/step)
# INFO:tensorflow:global step 18340: loss = 0.0093 (0.110 sec/step)
# INFO:tensorflow:global step 18350: loss = 0.0766 (0.104 sec/step)
# INFO:tensorflow:global step 18360: loss = 0.0135 (0.115 sec/step)
# INFO:tensorflow:global step 18370: loss = 0.0504 (0.109 sec/step)
# INFO:tensorflow:global step 18380: loss = 0.0089 (0.107 sec/step)
# INFO:tensorflow:global step 18390: loss = 0.0506 (0.101 sec/step)
# INFO:tensorflow:global step 18400: loss = 0.0275 (0.101 sec/step)
# INFO:tensorflow:global step 18410: loss = 0.0050 (0.103 sec/step)
# INFO:tensorflow:global step 18420: loss = 0.0154 (0.103 sec/step)
# INFO:tensorflow:global step 18430: loss = 0.0058 (0.101 sec/step)
# INFO:tensorflow:global step 18440: loss = 0.0009 (0.102 sec/step)
# INFO:tensorflow:global step 18450: loss = 0.0033 (0.101 sec/step)
# INFO:tensorflow:global step 18460: loss = 0.0021 (0.109 sec/step)
# INFO:tensorflow:global step 18470: loss = 0.0115 (0.113 sec/step)
# INFO:tensorflow:global step 18480: loss = 0.0306 (0.115 sec/step)
# INFO:tensorflow:global step 18490: loss = 0.0086 (0.099 sec/step)
# INFO:tensorflow:global step 18500: loss = 0.0890 (0.101 sec/step)
# INFO:tensorflow:global step 18510: loss = 0.0356 (0.113 sec/step)
# INFO:tensorflow:global step 18520: loss = 0.0018 (0.110 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/lelu1/model.ckpt
# INFO:tensorflow:global step 18530: loss = 0.0334 (0.129 sec/step)
# INFO:tensorflow:Recording summary at step 18530.
# INFO:tensorflow:global step 18540: loss = 0.0070 (0.109 sec/step)
# INFO:tensorflow:global step 18550: loss = 0.0572 (0.108 sec/step)
# INFO:tensorflow:global step 18560: loss = 0.0254 (0.103 sec/step)
# INFO:tensorflow:global step 18570: loss = 0.0117 (0.113 sec/step)
# INFO:tensorflow:global step 18580: loss = 0.0343 (0.113 sec/step)
# INFO:tensorflow:global step 18590: loss = 0.0124 (0.103 sec/step)
# INFO:tensorflow:global step 18600: loss = 0.0486 (0.113 sec/step)
# INFO:tensorflow:global step 18610: loss = 0.0038 (0.104 sec/step)
# INFO:tensorflow:global step 18620: loss = 0.0101 (0.122 sec/step)
# INFO:tensorflow:global step 18630: loss = 0.0112 (0.108 sec/step)
# INFO:tensorflow:global step 18640: loss = 0.0019 (0.114 sec/step)
# INFO:tensorflow:global step 18650: loss = 0.0280 (0.103 sec/step)
# INFO:tensorflow:global step 18660: loss = 0.0150 (0.106 sec/step)
# INFO:tensorflow:global step 18670: loss = 0.0730 (0.109 sec/step)
# INFO:tensorflow:global step 18680: loss = 0.0044 (0.110 sec/step)
# INFO:tensorflow:global step 18690: loss = 0.0235 (0.105 sec/step)
# INFO:tensorflow:global step 18700: loss = 0.0325 (0.107 sec/step)
# INFO:tensorflow:global step 18710: loss = 0.0586 (0.099 sec/step)
# INFO:tensorflow:global step 18720: loss = 0.0090 (0.102 sec/step)
# INFO:tensorflow:global step 18730: loss = 0.0651 (0.099 sec/step)
# INFO:tensorflow:global step 18740: loss = 0.1192 (0.105 sec/step)
# INFO:tensorflow:global step 18750: loss = 0.0023 (0.100 sec/step)
# INFO:tensorflow:global step 18760: loss = 0.0097 (0.113 sec/step)
# INFO:tensorflow:global step 18770: loss = 0.0051 (0.113 sec/step)
# INFO:tensorflow:global step 18780: loss = 0.0366 (0.109 sec/step)
# INFO:tensorflow:global step 18790: loss = 0.0011 (0.110 sec/step)
# INFO:tensorflow:global step 18800: loss = 0.0194 (0.101 sec/step)
# INFO:tensorflow:global step 18810: loss = 0.0138 (0.115 sec/step)
# INFO:tensorflow:global step 18820: loss = 0.0411 (0.106 sec/step)
# INFO:tensorflow:global step 18830: loss = 0.0033 (0.117 sec/step)
# INFO:tensorflow:global step 18840: loss = 0.0322 (0.104 sec/step)
# INFO:tensorflow:global step 18850: loss = 0.0094 (0.106 sec/step)
# INFO:tensorflow:global step 18860: loss = 0.0130 (0.117 sec/step)
# INFO:tensorflow:global step 18870: loss = 0.0403 (0.100 sec/step)
# INFO:tensorflow:global step 18880: loss = 0.0128 (0.109 sec/step)
# INFO:tensorflow:global step 18890: loss = 0.0593 (0.105 sec/step)
# INFO:tensorflow:global step 18900: loss = 0.0271 (0.103 sec/step)
# INFO:tensorflow:global step 18910: loss = 0.0776 (0.100 sec/step)
# INFO:tensorflow:global step 18920: loss = 0.1193 (0.104 sec/step)
# INFO:tensorflow:global step 18930: loss = 0.0667 (0.106 sec/step)
# INFO:tensorflow:global step 18940: loss = 0.0142 (0.112 sec/step)
# INFO:tensorflow:global step 18950: loss = 0.0506 (0.106 sec/step)
# INFO:tensorflow:global step 18960: loss = 0.0238 (0.112 sec/step)
# INFO:tensorflow:global step 18970: loss = 0.0593 (0.101 sec/step)
# INFO:tensorflow:global step 18980: loss = 0.0152 (0.106 sec/step)
# INFO:tensorflow:global step 18990: loss = 0.0048 (0.102 sec/step)
# INFO:tensorflow:global step 19000: loss = 0.0007 (0.111 sec/step)
# INFO:tensorflow:global step 19010: loss = 0.0304 (0.108 sec/step)
# INFO:tensorflow:global step 19020: loss = 0.0443 (0.105 sec/step)
# INFO:tensorflow:global step 19030: loss = 0.0521 (0.106 sec/step)
# INFO:tensorflow:global step 19040: loss = 0.0303 (0.105 sec/step)
# INFO:tensorflow:global step 19050: loss = 0.0220 (0.106 sec/step)
# INFO:tensorflow:global step 19060: loss = 0.0144 (0.102 sec/step)
# INFO:tensorflow:global step 19070: loss = 0.0322 (0.111 sec/step)
# INFO:tensorflow:global step 19080: loss = 0.0045 (0.105 sec/step)
# INFO:tensorflow:global step 19090: loss = 0.0187 (0.100 sec/step)
# INFO:tensorflow:global step 19100: loss = 0.0025 (0.111 sec/step)
# INFO:tensorflow:global step 19110: loss = 0.0343 (0.100 sec/step)
# INFO:tensorflow:global step 19120: loss = 0.0354 (0.104 sec/step)
# INFO:tensorflow:global step 19130: loss = 0.0231 (0.101 sec/step)
# INFO:tensorflow:global step 19140: loss = 0.0117 (0.103 sec/step)
# INFO:tensorflow:global step 19150: loss = 0.0038 (0.112 sec/step)
# INFO:tensorflow:global step 19160: loss = 0.0063 (0.105 sec/step)
# INFO:tensorflow:global step 19170: loss = 0.0106 (0.106 sec/step)
# INFO:tensorflow:global step 19180: loss = 0.0397 (0.108 sec/step)
# INFO:tensorflow:global step 19190: loss = 0.0050 (0.104 sec/step)
# INFO:tensorflow:global step 19200: loss = 0.0516 (0.100 sec/step)
# INFO:tensorflow:global step 19210: loss = 0.0087 (0.101 sec/step)
# INFO:tensorflow:global step 19220: loss = 0.0028 (0.121 sec/step)
# INFO:tensorflow:global step 19230: loss = 0.0086 (0.113 sec/step)
# INFO:tensorflow:global step 19240: loss = 0.0164 (0.100 sec/step)
# INFO:tensorflow:global step 19250: loss = 0.0259 (0.102 sec/step)
# INFO:tensorflow:global step 19260: loss = 0.0067 (0.112 sec/step)
# INFO:tensorflow:global step 19270: loss = 0.0273 (0.118 sec/step)
# INFO:tensorflow:global step 19280: loss = 0.0595 (0.107 sec/step)
# INFO:tensorflow:global step 19290: loss = 0.0302 (0.105 sec/step)
# INFO:tensorflow:global step 19300: loss = 0.0185 (0.114 sec/step)
# INFO:tensorflow:global step 19310: loss = 0.0125 (0.100 sec/step)
# INFO:tensorflow:global step 19320: loss = 0.0042 (0.113 sec/step)
# INFO:tensorflow:global step 19330: loss = 0.0181 (0.102 sec/step)
# INFO:tensorflow:global step 19340: loss = 0.0070 (0.118 sec/step)
# INFO:tensorflow:global step 19350: loss = 0.0042 (0.109 sec/step)
# INFO:tensorflow:global step 19360: loss = 0.0038 (0.115 sec/step)
# INFO:tensorflow:global step 19370: loss = 0.0047 (0.104 sec/step)
# INFO:tensorflow:global step 19380: loss = 0.0389 (0.104 sec/step)
# INFO:tensorflow:global step 19390: loss = 0.0055 (0.106 sec/step)
# INFO:tensorflow:global step 19400: loss = 0.0180 (0.104 sec/step)
# INFO:tensorflow:global step 19410: loss = 0.0277 (0.102 sec/step)
# INFO:tensorflow:global step 19420: loss = 0.0264 (0.111 sec/step)
# INFO:tensorflow:global step 19430: loss = 0.0238 (0.100 sec/step)
# INFO:tensorflow:global step 19440: loss = 0.0330 (0.104 sec/step)
# INFO:tensorflow:global step 19450: loss = 0.0027 (0.100 sec/step)
# INFO:tensorflow:Saving checkpoint to path /tmp/cifar10/lelu1/model.ckpt
# INFO:tensorflow:Recording summary at step 19457.
# INFO:tensorflow:global step 19460: loss = 0.0101 (0.106 sec/step)
# INFO:tensorflow:global step 19470: loss = 0.0472 (0.101 sec/step)
# INFO:tensorflow:global step 19480: loss = 0.0267 (0.111 sec/step)
# INFO:tensorflow:global step 19490: loss = 0.0088 (0.106 sec/step)
# INFO:tensorflow:global step 19500: loss = 0.1078 (0.101 sec/step)
# INFO:tensorflow:global step 19510: loss = 0.0598 (0.100 sec/step)
# INFO:tensorflow:global step 19520: loss = 0.0562 (0.108 sec/step)
# INFO:tensorflow:global step 19530: loss = 0.0418 (0.108 sec/step)
# INFO:tensorflow:global step 19540: loss = 0.0457 (0.113 sec/step)
# INFO:tensorflow:global step 19550: loss = 0.0422 (0.103 sec/step)
# INFO:tensorflow:global step 19560: loss = 0.0100 (0.103 sec/step)
# INFO:tensorflow:global step 19570: loss = 0.0171 (0.099 sec/step)
# INFO:tensorflow:global step 19580: loss = 0.0040 (0.103 sec/step)
# INFO:tensorflow:global step 19590: loss = 0.0265 (0.107 sec/step)
# INFO:tensorflow:global step 19600: loss = 0.0141 (0.108 sec/step)
# INFO:tensorflow:global step 19610: loss = 0.0112 (0.102 sec/step)
# INFO:tensorflow:global step 19620: loss = 0.0429 (0.099 sec/step)
# INFO:tensorflow:global step 19630: loss = 0.0286 (0.100 sec/step)
# INFO:tensorflow:global step 19640: loss = 0.0236 (0.109 sec/step)
# INFO:tensorflow:global step 19650: loss = 0.0616 (0.108 sec/step)
# INFO:tensorflow:global step 19660: loss = 0.0107 (0.103 sec/step)
# INFO:tensorflow:global step 19670: loss = 0.0140 (0.108 sec/step)
# INFO:tensorflow:global step 19680: loss = 0.0622 (0.110 sec/step)
# INFO:tensorflow:global step 19690: loss = 0.0104 (0.107 sec/step)
# INFO:tensorflow:global step 19700: loss = 0.0158 (0.101 sec/step)
# INFO:tensorflow:global step 19710: loss = 0.0248 (0.102 sec/step)
# INFO:tensorflow:global step 19720: loss = 0.0549 (0.103 sec/step)
# INFO:tensorflow:global step 19730: loss = 0.1377 (0.108 sec/step)
# INFO:tensorflow:global step 19740: loss = 0.0148 (0.101 sec/step)
# INFO:tensorflow:global step 19750: loss = 0.0411 (0.104 sec/step)
# INFO:tensorflow:global step 19760: loss = 0.0268 (0.108 sec/step)
# INFO:tensorflow:global step 19770: loss = 0.0023 (0.109 sec/step)
# INFO:tensorflow:global step 19780: loss = 0.0203 (0.110 sec/step)
# INFO:tensorflow:global step 19790: loss = 0.0073 (0.110 sec/step)
# INFO:tensorflow:global step 19800: loss = 0.0150 (0.114 sec/step)
# INFO:tensorflow:global step 19810: loss = 0.0028 (0.100 sec/step)
# INFO:tensorflow:global step 19820: loss = 0.0399 (0.116 sec/step)
# INFO:tensorflow:global step 19830: loss = 0.0364 (0.112 sec/step)
# INFO:tensorflow:global step 19840: loss = 0.0070 (0.105 sec/step)
# INFO:tensorflow:global step 19850: loss = 0.0360 (0.112 sec/step)
# INFO:tensorflow:global step 19860: loss = 0.0034 (0.101 sec/step)
# INFO:tensorflow:global step 19870: loss = 0.0328 (0.099 sec/step)
# INFO:tensorflow:global step 19880: loss = 0.0047 (0.104 sec/step)
# INFO:tensorflow:global step 19890: loss = 0.0207 (0.108 sec/step)
# INFO:tensorflow:global step 19900: loss = 0.0235 (0.106 sec/step)
# INFO:tensorflow:global step 19910: loss = 0.0037 (0.107 sec/step)
# INFO:tensorflow:global step 19920: loss = 0.0252 (0.099 sec/step)
# INFO:tensorflow:global step 19930: loss = 0.0149 (0.104 sec/step)
# INFO:tensorflow:global step 19940: loss = 0.0016 (0.105 sec/step)
# INFO:tensorflow:global step 19950: loss = 0.0050 (0.105 sec/step)
# INFO:tensorflow:global step 19960: loss = 0.0084 (0.106 sec/step)
# INFO:tensorflow:global step 19970: loss = 0.0367 (0.107 sec/step)
# INFO:tensorflow:global step 19980: loss = 0.0522 (0.101 sec/step)
# INFO:tensorflow:global step 19990: loss = 0.0212 (0.100 sec/step)
# INFO:tensorflow:global step 20000: loss = 0.0047 (0.099 sec/step)
# INFO:tensorflow:Stopping Training.
# INFO:tensorflow:Finished training! Saving model to disk.
# Finished training. Final batch loss 0
# CPU times: user 1h 54min 9s, sys: 24min 12s, total: 2h 18min 22s
# Wall time: 36min 1s

# %%
# %%time

# This might take a few minutes.
with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.DEBUG)
    
    dataset = cifar10.get_split('test', cifar10_data_dir)
    images, _, labels = load_batch(dataset)
    
    logits = cnn_relu(images, num_classes=dataset.num_classes, is_training=False)
    predictions = tf.argmax(logits, 1)
    
    # Define the metrics:
    names_to_values, names_to_updates = slim.metrics.aggregate_metric_map({
        'eval/mse':slim.metrics.streaming_mean_squared_error(predictions, labels),
        'eval/Accuracy': slim.metrics.streaming_accuracy(predictions, labels),
        'eval/TruePositives': slim.metrics.streaming_true_positives(predictions, labels),        
        'eval/TrueNegatives': slim.metrics.streaming_true_negatives(predictions, labels),
        'eval/FalsePositives': slim.metrics.streaming_false_positives(predictions, labels),
        'eval/FalseNegatives': slim.metrics.streaming_false_negatives(predictions, labels),
        'eval/Recall5': slim.metrics.streaming_sparse_recall_at_k(logits, labels, 5),
    })

    print('Running evaluation Loop...')
    checkpoint_path = tf.train.latest_checkpoint(train_dir)
    metric_values = slim.evaluation.evaluate_once(
        master='',
        checkpoint_path=checkpoint_path,
        logdir=train_dir,
        eval_op=list(names_to_updates.values()),
        final_op=list(names_to_values.values())
    )

    names_to_values = dict(zip(names_to_values.keys(), metric_values))
    for name in names_to_values:
        print('%s: %f' % (name, names_to_values[name]))
# Out:
# WARNING:tensorflow:From <timed exec>:15: streaming_accuracy (from tensorflow.contrib.metrics.python.ops.metric_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.metrics.accuracy. Note that the order of the inputs of labels and predictions have been switched.
# Running evaluation Loop...
# INFO:tensorflow:Starting evaluation at 2017-12-03-03:23:24
# INFO:tensorflow:Restoring parameters from /tmp/cifar10/lelu1/model.ckpt-20000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-12-03-03:23:24
# eval/Recall5: 0.984375
# eval/FalseNegatives: 2.000000
# eval/FalsePositives: 4.000000
# eval/mse: 3.921875
# eval/Accuracy: 0.789062
# eval/TrueNegatives: 7.000000
# eval/TruePositives: 115.000000
# CPU times: user 1.62 s, sys: 264 ms, total: 1.89 s
# Wall time: 1.13 s

# %%
# %%time
batch_size = 10
with tf.Graph().as_default():
    tf.logging.set_verbosity(tf.logging.INFO)
    
    dataset = cifar10.get_split('test',cifar10_data_dir)
    images, images_raw, labels = load_batch(dataset, height=image_size, width=image_size)
    
    # Create the model, use the default arg scope to configure the batch norm parameters.
    logits = cnn_relu(images, num_classes=dataset.num_classes, is_training=True)
    probabilities = tf.nn.softmax(logits)
    
    checkpoint_path = tf.train.latest_checkpoint(train_dir)
    init_fn = slim.assign_from_checkpoint_fn(
      checkpoint_path,
      slim.get_variables_to_restore())
    
    with tf.Session() as sess:
        with slim.queues.QueueRunners(sess):
            sess.run(tf.local_variables_initializer())
            init_fn(sess)
            np_probabilities, np_images_raw, np_labels = sess.run([probabilities, images_raw, labels])
    
            for i in range(batch_size): 
                image = np_images_raw[i, :, :, :]
                true_label = np_labels[i]
                predicted_label = np.argmax(np_probabilities[i, :])
                predicted_name = dataset.labels_to_names[predicted_label]
                true_name = dataset.labels_to_names[true_label]
                
                plt.figure()
                plt.imshow(image.astype(np.uint8))
                plt.title('Ground Truth: [%s], Prediction [%s]' % (true_name, predicted_name))
                plt.axis('off')
                plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/cifar10/lelu1/model.ckpt-20000
# CPU times: user 3.3 s, sys: 1.84 s, total: 5.13 s
# Wall time: 1.71 s
